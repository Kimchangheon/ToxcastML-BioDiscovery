# %% [markdown]
# # Data download from GCP

# %%
import pandas as pd
# !gsutil cp gs://chem_dsrc/P0_Toxcast/Data/assay_df/335_all_assay_df_df.csv ./
# Out:
# Copying gs://chem_dsrc/P0_Toxcast/Data/assay_df/335_all_assay_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/Data/assay_df/NCCT_TPO_AUR_dn_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/Data/assay_df/NVS_ADME_hCYP1A2_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/Data/assay_df/NVS_ADME_hCYP2B6_df.csv...
# / [4 files][  4.3 MiB/  4.3 MiB]
# Operation completed over 4 objects/4.3 MiB.

# %%
# rdkit 2020.03.3 버전 다운로드
# !pip install kora -q
import kora.install.rdkit
import numpy
import pandas
import numpy as np
import pandas as pd

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit.Chem import Draw
from rdkit.Chem.Draw import SimilarityMaps
from rdkit import Chem, DataStructs
from rdkit.Chem import MACCSkeys

from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import StratifiedKFold

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import matthews_corrcoef

from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from imblearn.combine import SMOTEENN 
from sklearn import metrics
# Out:
#      |████████████████████████████████| 61kB 3.4MB/s
#      |████████████████████████████████| 61kB 5.3MB/s
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import os 
import time

ffpp_list = ['maccs', 'morgan','rdkit','pattern','layerd']
algo_list = ['MLP','GBT','RF','LR','KNN','NB']

dir_path = './result_sklearn_all_a_fp/'
os.mkdir(dir_path)
os.mkdir(dir_path + "metric/")

for i in ffpp_list : 
  os.mkdir(dir_path + "metric/"+i)

for i in ffpp_list : 
  for algo in algo_list :
    os.mkdir(dir_path + "metric/"+i+'/'+algo)

# %%
def g_tf(ss_fp) : 

  
  # ss_fp = a_p_list[10]
  ffpp = ss_fp[0]#fingerfrint name
  ss =ss_fp[1]#assay name
  algo = ss_fp[2]

  start_time = time.time()
  print(ffpp ,algo, ss, 'start!_______________________________')

  df_ss = df.loc[:,['smiles',ss]]
  df_ss = df_ss.dropna()
  assays_ss = df_ss.columns

  #Smiles --> MACCS Keys
  assay = ss
  df_train  = df_ss[['smiles',ss] ]

  smiles_list = []
  err_smiles = []# fingerfrint로 변환시 에러 smiles
  fps = []
  enc_y = []
  for index, row in df_train.iterrows():

    if row[-1] == 'N' : 
      target = 0
    else :
      target = 1

    try : 
      mol = Chem.MolFromSmiles(row['smiles'])
      
      if ffpp == 'maccs' :    
          fp = MACCSkeys.GenMACCSKeys(mol)
      elif ffpp == 'morgan' : 
          fp = Chem.AllChem.GetMorganFingerprintAsBitVect(mol, 2)
      elif ffpp == 'rdkit' : 
          fp = Chem.RDKFingerprint(mol)
      elif ffpp == 'pattern' : 
          fp = Chem.rdmolops.PatternFingerprint(mol)
      elif ffpp == 'layerd' : 
          fp = Chem.rdmolops.LayeredFingerprint(mol)
      else : 
          print("fingerfrint selection error!")
          
      smiles_list.append(row['smiles'])   
      fps.append(fp)
      enc_y.append(target)
    except : 
      err_smiles.append(row['smiles'])
      pass

  np_fps = []
  for fp in fps:
    arr = numpy.zeros((1,))
    DataStructs.ConvertToNumpyArray(fp, arr)
    np_fps.append(arr)

  np_fps_array = numpy.array(np_fps)

  # print("변환 에러난 smiles 개수 : ", len(err_smiles), err_smiles)

  x_train_res, y_train_res = np_fps_array, np.array(enc_y)
  train = pd.DataFrame(data=x_train_res)
  train['label'] = y_train_res

  d = pd.DataFrame(columns = ['smiles','Type'] )
  d['smiles'] = smiles_list
  d['Type'] = enc_y

  #모든 물질에 대한 fingerprint를 string형태로 바꾼다(비교하기위함).
  mychems = []
  for item in np_fps:
      #print(item)
      item = np.array(item,dtype=int) #왜 굳이 두번? int형으로 추가하려면 이렇게 하면 되는구나....
      s = item.tolist() #넘파이어레이를 리스트로 바꾼다. 
      t = [str(i) for i in s]
      mychems.append(''.join(t))

  i = 0
  counter = 0
  chemdict = {} #딗셔너리.
  listofdups = []
  for item in mychems:
      try:
          chemdict[str(item)].append(i)
          #print('dup found')
          for j in range(len(chemdict[str(item)])):
              if (d['Type'][i] != d['Type'][chemdict[str(item)][j]]) :
                  listofdups.append(i)
                  counter+=1
      except: 
          #print('adding new')
          chemdict[str(item)] = []
          chemdict[str(item)].append(i)
      i+=1
  # print(str(counter)+' '+str(len(list(set(listofdups)))))
  #smote적용하기 전에서 listofdups를 빼면 된다!

  dups_list = list(set(listofdups))

  dups_list_0 = []
  for index in dups_list : 
    if train.iloc[index].label == 0 :
      dups_list_0.append(index)

  train = train.drop(dups_list_0)

  #분산이 0인 feature 제거
  train = train.loc[ :, train.std() > 0]



  # rskf = RepeatedStratifiedKFold(n_splits=10, n_repeats=10, random_state=36851234) 
  rskf = StratifiedKFold(n_splits = 10, random_state = 42)
  sme = SMOTEENN(random_state=42,sampling_strategy = "minority")

  X = np.array( train.drop('label', axis =1) )
  y = np.array(train.label)

  count = 0 
  rep = 0

  metric_df = pd.DataFrame(columns = ['AUC','B_A','Recall','Precision','F1','MCC','Accuracy'])
  metric_fold_df = pd.DataFrame(columns = ['AUC','B_A','Recall','Precision','F1','MCC','Accuracy'])

  for train_index, test_index in rskf.split(X, y): 
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    if ss in ['NVS_ADME_hCYP1A2' , 'NVS_ADME_hCYP2B6' , 'NCCT_TPO_AUR_dn'] : 
      pass
    else : 
      print("SMOTEENN fitiing....",ffpp,algo,ss)
      X_train, y_train = sme.fit_sample(X_train, list(y_train) )
      print("....End fitiing",ffpp, ss)

    if algo == 'MLP' : 
      clf = MLPClassifier()
    if algo == 'GBT' : 
      clf = GradientBoostingClassifier()
    if algo == 'RF' : 
      clf = RandomForestClassifier()
    if algo == 'LR' : 
      clf = LogisticRegression()
    if algo == 'KNN' : 
      clf = KNeighborsClassifier()
    if algo == 'NB' : 
      clf = GaussianNB()

    clf.fit(X_train, y_train)

    result =  clf.predict_proba(X_test) # 첫 클래스의 예측확률, 두번째 클래스의 예측 확률 어떤것이 0, 1이지?
    y_pred = clf.predict(X_test)
    conf_mat = confusion_matrix(y_test,y_pred)
    tn, fp, fn, tp = conf_mat.ravel()

    auc =  roc_auc_score(y_test,result[:,1] )
    recall = tp/(tp+fn) # 실제 1인 것 중 모델이 1이라 한것의 비율
    specificity = tn / (fp+tn) # 실제 0인 것중 모델이 0이라한것의 비율
    b_a = (recall + specificity) / 2
    precision =  tp / (tp+fp)
    F1 = 2* (precision * recall) / (precision + recall)
    MCC = matthews_corrcoef(y_test,y_pred)
    accuracy = clf.score(X_test,y_test)


    metric_fold_df = metric_fold_df.append(pd.DataFrame([[auc,b_a,recall,precision,F1,MCC,accuracy]],columns = ['AUC','B_A','Recall','Precision','F1','MCC','Accuracy']) )
    count +=1
    # print(ffpp, ss, count)
    if count % 10 == 0 :
      average = metric_fold_df.mean()
      std = metric_fold_df.std()
      metric_fold_df = metric_fold_df.append(average.to_frame().T)
      metric_fold_df = metric_fold_df.append(std.to_frame().T)
      metric_fold_df = round(metric_fold_df ,4)
      metric_fold_df.index = [str(rep) +'_' +  str(i) for i in range(10)]+ [str(rep)+'_Mean' , str(rep)+'_SD']
      metric_df = metric_df.append(metric_fold_df)
      metric_fold_df = pd.DataFrame(columns = ['AUC','B_A','Recall','Precision','F1','MCC','Accuracy'])
      rep += 1
      # print(ffpp, ss, rep)
    

  #전체 평균내기.
  bool_list = [] 
  for i in metric_df.index :
    if'Mean' in i  or 'SD' in i : 
      bool_list.append(False) 
    else : 
      bool_list.append(True)

  average = metric_df[bool_list].mean().to_frame().T
  average.index = ['Mean']
  std = metric_df[bool_list].std().to_frame().T
  std.index =['SD']

  metric_df = metric_df.append(round(average,4) )
  metric_df = metric_df.append(round(std,4))
  metric_df.to_csv(dir_path+"metric/"+ffpp+'/'+algo+'/'+ss+"_metric.csv")
  # end_time = time.time()
  print(ffpp ,algo, ss, 'end','time spent',start_time - time.time())

# %%
selected_assay_list = ['NVS_ADME_hCYP1A2' , 'NVS_ADME_hCYP2B6' , 'NCCT_TPO_AUR_dn','TOX21_AhR_LUC_Agonist', 'TOX21_Aromatase_Inhibition', 'TOX21_VDR_BLA_agonist_ratio', 'TOX21_VDR_BLA_antagonist_ratio', 'TOX21_AR_BLA_Agonist_ratio', 'TOX21_AR_BLA_Antagonist_ratio', 'TOX21_AR_LUC_MDAKB2_Agonist', 'TOX21_p53_BLA_p1_ratio', 'TOX21_p53_BLA_p2_ratio', 'TOX21_p53_BLA_p3_ratio', 'TOX21_p53_BLA_p4_ratio', 'TOX21_p53_BLA_p5_ratio', 'TOX21_HSE_BLA_agonist_ratio', 'TOX21_ELG1_LUC_Agonist', 'TOX21_ERa_BLA_Agonist_ratio', 'TOX21_ERa_BLA_Antagonist_ratio', 'TOX21_ESRE_BLA_ratio', 'TOX21_FXR_BLA_agonist_ratio', 'TOX21_FXR_BLA_antagonist_ratio', 'TOX21_GR_BLA_Agonist_ratio', 'TOX21_GR_BLA_Antagonist_ratio', 'TOX21_NFkB_BLA_agonist_ratio', 'TOX21_ARE_BLA_agonist_ratio', 'TOX21_TR_LUC_GH3_Agonist', 'TOX21_TR_LUC_GH3_Antagonist', 'TOX21_PPARg_BLA_Agonist_ratio', 'TOX21_PPARd_BLA_agonist_ratio', 'TOX21_PPARd_BLA_antagonist_ratio', 'TOX21_PPARg_BLA_antagonist_ratio']
selected_assay_list.remove('TOX21_NFkB_BLA_agonist_ratio')

ffpp_list = ['maccs', 'morgan','rdkit','pattern','layerd']

algo_list = ['MLP','GBT','RF','LR','KNN','NB']

a_p_list = []
for p in ffpp_list :
  for a in selected_assay_list : 
    for algo in algo_list :
      a_p_list.append([p,a,algo]) 

assay_name = '335_all_assay'
df = pd.read_csv(assay_name+"_df.csv")

# %%
a_p_list
# Out:
# [['maccs', 'NVS_ADME_hCYP1A2', 'MLP'],
#  ['maccs', 'NVS_ADME_hCYP1A2', 'GBT'],
#  ['maccs', 'NVS_ADME_hCYP1A2', 'RF'],
#  ['maccs', 'NVS_ADME_hCYP1A2', 'LR'],
#  ['maccs', 'NVS_ADME_hCYP1A2', 'KNN'],
#  ['maccs', 'NVS_ADME_hCYP1A2', 'NB'],
#  ['maccs', 'NVS_ADME_hCYP2B6', 'MLP'],
#  ['maccs', 'NVS_ADME_hCYP2B6', 'GBT'],
#  ['maccs', 'NVS_ADME_hCYP2B6', 'RF'],
#  ['maccs', 'NVS_ADME_hCYP2B6', 'LR'],
#  ['maccs', 'NVS_ADME_hCYP2B6', 'KNN'],
#  ['maccs', 'NVS_ADME_hCYP2B6', 'NB'],
#  ['maccs', 'NCCT_TPO_AUR_dn', 'MLP'],
#  ['maccs', 'NCCT_TPO_AUR_dn', 'GBT'],
#  ['maccs', 'NCCT_TPO_AUR_dn', 'RF'],
#  ['maccs', 'NCCT_TPO_AUR_dn', 'LR'],
#  ['maccs', 'NCCT_TPO_AUR_dn', 'KNN'],
#  ['maccs', 'NCCT_TPO_AUR_dn', 'NB'],
#  ['maccs', 'TOX21_AhR_LUC_Agonist', 'MLP'],
#  ['maccs', 'TOX21_AhR_LUC_Agonist', 'GBT'],
#  ['maccs', 'TOX21_AhR_LUC_Agonist', 'RF'],
#  ['maccs', 'TOX21_AhR_LUC_Agonist', 'LR'],
#  ['maccs', 'TOX21_AhR_LUC_Agonist', 'KNN'],
#  ['maccs', 'TOX21_AhR_LUC_Agonist', 'NB'],
#  ['maccs', 'TOX21_Aromatase_Inhibition', 'MLP'],
#  ['maccs', 'TOX21_Aromatase_Inhibition', 'GBT'],
#  ['maccs', 'TOX21_Aromatase_Inhibition', 'RF'],
#  ['maccs', 'TOX21_Aromatase_Inhibition', 'LR'],
#  ['maccs', 'TOX21_Aromatase_Inhibition', 'KNN'],
#  ['maccs', 'TOX21_Aromatase_Inhibition', 'NB'],
#  ['maccs', 'TOX21_VDR_BLA_agonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_VDR_BLA_agonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_VDR_BLA_agonist_ratio', 'RF'],
#  ['maccs', 'TOX21_VDR_BLA_agonist_ratio', 'LR'],
#  ['maccs', 'TOX21_VDR_BLA_agonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_VDR_BLA_agonist_ratio', 'NB'],
#  ['maccs', 'TOX21_VDR_BLA_antagonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_VDR_BLA_antagonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_VDR_BLA_antagonist_ratio', 'RF'],
#  ['maccs', 'TOX21_VDR_BLA_antagonist_ratio', 'LR'],
#  ['maccs', 'TOX21_VDR_BLA_antagonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_VDR_BLA_antagonist_ratio', 'NB'],
#  ['maccs', 'TOX21_AR_BLA_Agonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_AR_BLA_Agonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_AR_BLA_Agonist_ratio', 'RF'],
#  ['maccs', 'TOX21_AR_BLA_Agonist_ratio', 'LR'],
#  ['maccs', 'TOX21_AR_BLA_Agonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_AR_BLA_Agonist_ratio', 'NB'],
#  ['maccs', 'TOX21_AR_BLA_Antagonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_AR_BLA_Antagonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_AR_BLA_Antagonist_ratio', 'RF'],
#  ['maccs', 'TOX21_AR_BLA_Antagonist_ratio', 'LR'],
#  ['maccs', 'TOX21_AR_BLA_Antagonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_AR_BLA_Antagonist_ratio', 'NB'],
#  ['maccs', 'TOX21_AR_LUC_MDAKB2_Agonist', 'MLP'],
#  ['maccs', 'TOX21_AR_LUC_MDAKB2_Agonist', 'GBT'],
#  ['maccs', 'TOX21_AR_LUC_MDAKB2_Agonist', 'RF'],
#  ['maccs', 'TOX21_AR_LUC_MDAKB2_Agonist', 'LR'],
#  ['maccs', 'TOX21_AR_LUC_MDAKB2_Agonist', 'KNN'],
#  ['maccs', 'TOX21_AR_LUC_MDAKB2_Agonist', 'NB'],
#  ['maccs', 'TOX21_p53_BLA_p1_ratio', 'MLP'],
#  ['maccs', 'TOX21_p53_BLA_p1_ratio', 'GBT'],
#  ['maccs', 'TOX21_p53_BLA_p1_ratio', 'RF'],
#  ['maccs', 'TOX21_p53_BLA_p1_ratio', 'LR'],
#  ['maccs', 'TOX21_p53_BLA_p1_ratio', 'KNN'],
#  ['maccs', 'TOX21_p53_BLA_p1_ratio', 'NB'],
#  ['maccs', 'TOX21_p53_BLA_p2_ratio', 'MLP'],
#  ['maccs', 'TOX21_p53_BLA_p2_ratio', 'GBT'],
#  ['maccs', 'TOX21_p53_BLA_p2_ratio', 'RF'],
#  ['maccs', 'TOX21_p53_BLA_p2_ratio', 'LR'],
#  ['maccs', 'TOX21_p53_BLA_p2_ratio', 'KNN'],
#  ['maccs', 'TOX21_p53_BLA_p2_ratio', 'NB'],
#  ['maccs', 'TOX21_p53_BLA_p3_ratio', 'MLP'],
#  ['maccs', 'TOX21_p53_BLA_p3_ratio', 'GBT'],
#  ['maccs', 'TOX21_p53_BLA_p3_ratio', 'RF'],
#  ['maccs', 'TOX21_p53_BLA_p3_ratio', 'LR'],
#  ['maccs', 'TOX21_p53_BLA_p3_ratio', 'KNN'],
#  ['maccs', 'TOX21_p53_BLA_p3_ratio', 'NB'],
#  ['maccs', 'TOX21_p53_BLA_p4_ratio', 'MLP'],
#  ['maccs', 'TOX21_p53_BLA_p4_ratio', 'GBT'],
#  ['maccs', 'TOX21_p53_BLA_p4_ratio', 'RF'],
#  ['maccs', 'TOX21_p53_BLA_p4_ratio', 'LR'],
#  ['maccs', 'TOX21_p53_BLA_p4_ratio', 'KNN'],
#  ['maccs', 'TOX21_p53_BLA_p4_ratio', 'NB'],
#  ['maccs', 'TOX21_p53_BLA_p5_ratio', 'MLP'],
#  ['maccs', 'TOX21_p53_BLA_p5_ratio', 'GBT'],
#  ['maccs', 'TOX21_p53_BLA_p5_ratio', 'RF'],
#  ['maccs', 'TOX21_p53_BLA_p5_ratio', 'LR'],
#  ['maccs', 'TOX21_p53_BLA_p5_ratio', 'KNN'],
#  ['maccs', 'TOX21_p53_BLA_p5_ratio', 'NB'],
#  ['maccs', 'TOX21_HSE_BLA_agonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_HSE_BLA_agonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_HSE_BLA_agonist_ratio', 'RF'],
#  ['maccs', 'TOX21_HSE_BLA_agonist_ratio', 'LR'],
#  ['maccs', 'TOX21_HSE_BLA_agonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_HSE_BLA_agonist_ratio', 'NB'],
#  ['maccs', 'TOX21_ELG1_LUC_Agonist', 'MLP'],
#  ['maccs', 'TOX21_ELG1_LUC_Agonist', 'GBT'],
#  ['maccs', 'TOX21_ELG1_LUC_Agonist', 'RF'],
#  ['maccs', 'TOX21_ELG1_LUC_Agonist', 'LR'],
#  ['maccs', 'TOX21_ELG1_LUC_Agonist', 'KNN'],
#  ['maccs', 'TOX21_ELG1_LUC_Agonist', 'NB'],
#  ['maccs', 'TOX21_ERa_BLA_Agonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_ERa_BLA_Agonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_ERa_BLA_Agonist_ratio', 'RF'],
#  ['maccs', 'TOX21_ERa_BLA_Agonist_ratio', 'LR'],
#  ['maccs', 'TOX21_ERa_BLA_Agonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_ERa_BLA_Agonist_ratio', 'NB'],
#  ['maccs', 'TOX21_ERa_BLA_Antagonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_ERa_BLA_Antagonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_ERa_BLA_Antagonist_ratio', 'RF'],
#  ['maccs', 'TOX21_ERa_BLA_Antagonist_ratio', 'LR'],
#  ['maccs', 'TOX21_ERa_BLA_Antagonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_ERa_BLA_Antagonist_ratio', 'NB'],
#  ['maccs', 'TOX21_ESRE_BLA_ratio', 'MLP'],
#  ['maccs', 'TOX21_ESRE_BLA_ratio', 'GBT'],
#  ['maccs', 'TOX21_ESRE_BLA_ratio', 'RF'],
#  ['maccs', 'TOX21_ESRE_BLA_ratio', 'LR'],
#  ['maccs', 'TOX21_ESRE_BLA_ratio', 'KNN'],
#  ['maccs', 'TOX21_ESRE_BLA_ratio', 'NB'],
#  ['maccs', 'TOX21_FXR_BLA_agonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_FXR_BLA_agonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_FXR_BLA_agonist_ratio', 'RF'],
#  ['maccs', 'TOX21_FXR_BLA_agonist_ratio', 'LR'],
#  ['maccs', 'TOX21_FXR_BLA_agonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_FXR_BLA_agonist_ratio', 'NB'],
#  ['maccs', 'TOX21_FXR_BLA_antagonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_FXR_BLA_antagonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_FXR_BLA_antagonist_ratio', 'RF'],
#  ['maccs', 'TOX21_FXR_BLA_antagonist_ratio', 'LR'],
#  ['maccs', 'TOX21_FXR_BLA_antagonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_FXR_BLA_antagonist_ratio', 'NB'],
#  ['maccs', 'TOX21_GR_BLA_Agonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_GR_BLA_Agonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_GR_BLA_Agonist_ratio', 'RF'],
#  ['maccs', 'TOX21_GR_BLA_Agonist_ratio', 'LR'],
#  ['maccs', 'TOX21_GR_BLA_Agonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_GR_BLA_Agonist_ratio', 'NB'],
#  ['maccs', 'TOX21_GR_BLA_Antagonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_GR_BLA_Antagonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_GR_BLA_Antagonist_ratio', 'RF'],
#  ['maccs', 'TOX21_GR_BLA_Antagonist_ratio', 'LR'],
#  ['maccs', 'TOX21_GR_BLA_Antagonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_GR_BLA_Antagonist_ratio', 'NB'],
#  ['maccs', 'TOX21_ARE_BLA_agonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_ARE_BLA_agonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_ARE_BLA_agonist_ratio', 'RF'],
#  ['maccs', 'TOX21_ARE_BLA_agonist_ratio', 'LR'],
#  ['maccs', 'TOX21_ARE_BLA_agonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_ARE_BLA_agonist_ratio', 'NB'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Agonist', 'MLP'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Agonist', 'GBT'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Agonist', 'RF'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Agonist', 'LR'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Agonist', 'KNN'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Agonist', 'NB'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Antagonist', 'MLP'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Antagonist', 'GBT'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Antagonist', 'RF'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Antagonist', 'LR'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Antagonist', 'KNN'],
#  ['maccs', 'TOX21_TR_LUC_GH3_Antagonist', 'NB'],
#  ['maccs', 'TOX21_PPARg_BLA_Agonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_PPARg_BLA_Agonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_PPARg_BLA_Agonist_ratio', 'RF'],
#  ['maccs', 'TOX21_PPARg_BLA_Agonist_ratio', 'LR'],
#  ['maccs', 'TOX21_PPARg_BLA_Agonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_PPARg_BLA_Agonist_ratio', 'NB'],
#  ['maccs', 'TOX21_PPARd_BLA_agonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_PPARd_BLA_agonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_PPARd_BLA_agonist_ratio', 'RF'],
#  ['maccs', 'TOX21_PPARd_BLA_agonist_ratio', 'LR'],
#  ['maccs', 'TOX21_PPARd_BLA_agonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_PPARd_BLA_agonist_ratio', 'NB'],
#  ['maccs', 'TOX21_PPARd_BLA_antagonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_PPARd_BLA_antagonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_PPARd_BLA_antagonist_ratio', 'RF'],
#  ['maccs', 'TOX21_PPARd_BLA_antagonist_ratio', 'LR'],
#  ['maccs', 'TOX21_PPARd_BLA_antagonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_PPARd_BLA_antagonist_ratio', 'NB'],
#  ['maccs', 'TOX21_PPARg_BLA_antagonist_ratio', 'MLP'],
#  ['maccs', 'TOX21_PPARg_BLA_antagonist_ratio', 'GBT'],
#  ['maccs', 'TOX21_PPARg_BLA_antagonist_ratio', 'RF'],
#  ['maccs', 'TOX21_PPARg_BLA_antagonist_ratio', 'LR'],
#  ['maccs', 'TOX21_PPARg_BLA_antagonist_ratio', 'KNN'],
#  ['maccs', 'TOX21_PPARg_BLA_antagonist_ratio', 'NB'],
#  ['morgan', 'NVS_ADME_hCYP1A2', 'MLP'],
#  ['morgan', 'NVS_ADME_hCYP1A2', 'GBT'],
#  ['morgan', 'NVS_ADME_hCYP1A2', 'RF'],
#  ['morgan', 'NVS_ADME_hCYP1A2', 'LR'],
#  ['morgan', 'NVS_ADME_hCYP1A2', 'KNN'],
#  ['morgan', 'NVS_ADME_hCYP1A2', 'NB'],
#  ['morgan', 'NVS_ADME_hCYP2B6', 'MLP'],
#  ['morgan', 'NVS_ADME_hCYP2B6', 'GBT'],
#  ['morgan', 'NVS_ADME_hCYP2B6', 'RF'],
#  ['morgan', 'NVS_ADME_hCYP2B6', 'LR'],
#  ['morgan', 'NVS_ADME_hCYP2B6', 'KNN'],
#  ['morgan', 'NVS_ADME_hCYP2B6', 'NB'],
#  ['morgan', 'NCCT_TPO_AUR_dn', 'MLP'],
#  ['morgan', 'NCCT_TPO_AUR_dn', 'GBT'],
#  ['morgan', 'NCCT_TPO_AUR_dn', 'RF'],
#  ['morgan', 'NCCT_TPO_AUR_dn', 'LR'],
#  ['morgan', 'NCCT_TPO_AUR_dn', 'KNN'],
#  ['morgan', 'NCCT_TPO_AUR_dn', 'NB'],
#  ['morgan', 'TOX21_AhR_LUC_Agonist', 'MLP'],
#  ['morgan', 'TOX21_AhR_LUC_Agonist', 'GBT'],
#  ['morgan', 'TOX21_AhR_LUC_Agonist', 'RF'],
#  ['morgan', 'TOX21_AhR_LUC_Agonist', 'LR'],
#  ['morgan', 'TOX21_AhR_LUC_Agonist', 'KNN'],
#  ['morgan', 'TOX21_AhR_LUC_Agonist', 'NB'],
#  ['morgan', 'TOX21_Aromatase_Inhibition', 'MLP'],
#  ['morgan', 'TOX21_Aromatase_Inhibition', 'GBT'],
#  ['morgan', 'TOX21_Aromatase_Inhibition', 'RF'],
#  ['morgan', 'TOX21_Aromatase_Inhibition', 'LR'],
#  ['morgan', 'TOX21_Aromatase_Inhibition', 'KNN'],
#  ['morgan', 'TOX21_Aromatase_Inhibition', 'NB'],
#  ['morgan', 'TOX21_VDR_BLA_agonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_VDR_BLA_agonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_VDR_BLA_agonist_ratio', 'RF'],
#  ['morgan', 'TOX21_VDR_BLA_agonist_ratio', 'LR'],
#  ['morgan', 'TOX21_VDR_BLA_agonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_VDR_BLA_agonist_ratio', 'NB'],
#  ['morgan', 'TOX21_VDR_BLA_antagonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_VDR_BLA_antagonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_VDR_BLA_antagonist_ratio', 'RF'],
#  ['morgan', 'TOX21_VDR_BLA_antagonist_ratio', 'LR'],
#  ['morgan', 'TOX21_VDR_BLA_antagonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_VDR_BLA_antagonist_ratio', 'NB'],
#  ['morgan', 'TOX21_AR_BLA_Agonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_AR_BLA_Agonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_AR_BLA_Agonist_ratio', 'RF'],
#  ['morgan', 'TOX21_AR_BLA_Agonist_ratio', 'LR'],
#  ['morgan', 'TOX21_AR_BLA_Agonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_AR_BLA_Agonist_ratio', 'NB'],
#  ['morgan', 'TOX21_AR_BLA_Antagonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_AR_BLA_Antagonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_AR_BLA_Antagonist_ratio', 'RF'],
#  ['morgan', 'TOX21_AR_BLA_Antagonist_ratio', 'LR'],
#  ['morgan', 'TOX21_AR_BLA_Antagonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_AR_BLA_Antagonist_ratio', 'NB'],
#  ['morgan', 'TOX21_AR_LUC_MDAKB2_Agonist', 'MLP'],
#  ['morgan', 'TOX21_AR_LUC_MDAKB2_Agonist', 'GBT'],
#  ['morgan', 'TOX21_AR_LUC_MDAKB2_Agonist', 'RF'],
#  ['morgan', 'TOX21_AR_LUC_MDAKB2_Agonist', 'LR'],
#  ['morgan', 'TOX21_AR_LUC_MDAKB2_Agonist', 'KNN'],
#  ['morgan', 'TOX21_AR_LUC_MDAKB2_Agonist', 'NB'],
#  ['morgan', 'TOX21_p53_BLA_p1_ratio', 'MLP'],
#  ['morgan', 'TOX21_p53_BLA_p1_ratio', 'GBT'],
#  ['morgan', 'TOX21_p53_BLA_p1_ratio', 'RF'],
#  ['morgan', 'TOX21_p53_BLA_p1_ratio', 'LR'],
#  ['morgan', 'TOX21_p53_BLA_p1_ratio', 'KNN'],
#  ['morgan', 'TOX21_p53_BLA_p1_ratio', 'NB'],
#  ['morgan', 'TOX21_p53_BLA_p2_ratio', 'MLP'],
#  ['morgan', 'TOX21_p53_BLA_p2_ratio', 'GBT'],
#  ['morgan', 'TOX21_p53_BLA_p2_ratio', 'RF'],
#  ['morgan', 'TOX21_p53_BLA_p2_ratio', 'LR'],
#  ['morgan', 'TOX21_p53_BLA_p2_ratio', 'KNN'],
#  ['morgan', 'TOX21_p53_BLA_p2_ratio', 'NB'],
#  ['morgan', 'TOX21_p53_BLA_p3_ratio', 'MLP'],
#  ['morgan', 'TOX21_p53_BLA_p3_ratio', 'GBT'],
#  ['morgan', 'TOX21_p53_BLA_p3_ratio', 'RF'],
#  ['morgan', 'TOX21_p53_BLA_p3_ratio', 'LR'],
#  ['morgan', 'TOX21_p53_BLA_p3_ratio', 'KNN'],
#  ['morgan', 'TOX21_p53_BLA_p3_ratio', 'NB'],
#  ['morgan', 'TOX21_p53_BLA_p4_ratio', 'MLP'],
#  ['morgan', 'TOX21_p53_BLA_p4_ratio', 'GBT'],
#  ['morgan', 'TOX21_p53_BLA_p4_ratio', 'RF'],
#  ['morgan', 'TOX21_p53_BLA_p4_ratio', 'LR'],
#  ['morgan', 'TOX21_p53_BLA_p4_ratio', 'KNN'],
#  ['morgan', 'TOX21_p53_BLA_p4_ratio', 'NB'],
#  ['morgan', 'TOX21_p53_BLA_p5_ratio', 'MLP'],
#  ['morgan', 'TOX21_p53_BLA_p5_ratio', 'GBT'],
#  ['morgan', 'TOX21_p53_BLA_p5_ratio', 'RF'],
#  ['morgan', 'TOX21_p53_BLA_p5_ratio', 'LR'],
#  ['morgan', 'TOX21_p53_BLA_p5_ratio', 'KNN'],
#  ['morgan', 'TOX21_p53_BLA_p5_ratio', 'NB'],
#  ['morgan', 'TOX21_HSE_BLA_agonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_HSE_BLA_agonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_HSE_BLA_agonist_ratio', 'RF'],
#  ['morgan', 'TOX21_HSE_BLA_agonist_ratio', 'LR'],
#  ['morgan', 'TOX21_HSE_BLA_agonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_HSE_BLA_agonist_ratio', 'NB'],
#  ['morgan', 'TOX21_ELG1_LUC_Agonist', 'MLP'],
#  ['morgan', 'TOX21_ELG1_LUC_Agonist', 'GBT'],
#  ['morgan', 'TOX21_ELG1_LUC_Agonist', 'RF'],
#  ['morgan', 'TOX21_ELG1_LUC_Agonist', 'LR'],
#  ['morgan', 'TOX21_ELG1_LUC_Agonist', 'KNN'],
#  ['morgan', 'TOX21_ELG1_LUC_Agonist', 'NB'],
#  ['morgan', 'TOX21_ERa_BLA_Agonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_ERa_BLA_Agonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_ERa_BLA_Agonist_ratio', 'RF'],
#  ['morgan', 'TOX21_ERa_BLA_Agonist_ratio', 'LR'],
#  ['morgan', 'TOX21_ERa_BLA_Agonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_ERa_BLA_Agonist_ratio', 'NB'],
#  ['morgan', 'TOX21_ERa_BLA_Antagonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_ERa_BLA_Antagonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_ERa_BLA_Antagonist_ratio', 'RF'],
#  ['morgan', 'TOX21_ERa_BLA_Antagonist_ratio', 'LR'],
#  ['morgan', 'TOX21_ERa_BLA_Antagonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_ERa_BLA_Antagonist_ratio', 'NB'],
#  ['morgan', 'TOX21_ESRE_BLA_ratio', 'MLP'],
#  ['morgan', 'TOX21_ESRE_BLA_ratio', 'GBT'],
#  ['morgan', 'TOX21_ESRE_BLA_ratio', 'RF'],
#  ['morgan', 'TOX21_ESRE_BLA_ratio', 'LR'],
#  ['morgan', 'TOX21_ESRE_BLA_ratio', 'KNN'],
#  ['morgan', 'TOX21_ESRE_BLA_ratio', 'NB'],
#  ['morgan', 'TOX21_FXR_BLA_agonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_FXR_BLA_agonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_FXR_BLA_agonist_ratio', 'RF'],
#  ['morgan', 'TOX21_FXR_BLA_agonist_ratio', 'LR'],
#  ['morgan', 'TOX21_FXR_BLA_agonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_FXR_BLA_agonist_ratio', 'NB'],
#  ['morgan', 'TOX21_FXR_BLA_antagonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_FXR_BLA_antagonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_FXR_BLA_antagonist_ratio', 'RF'],
#  ['morgan', 'TOX21_FXR_BLA_antagonist_ratio', 'LR'],
#  ['morgan', 'TOX21_FXR_BLA_antagonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_FXR_BLA_antagonist_ratio', 'NB'],
#  ['morgan', 'TOX21_GR_BLA_Agonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_GR_BLA_Agonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_GR_BLA_Agonist_ratio', 'RF'],
#  ['morgan', 'TOX21_GR_BLA_Agonist_ratio', 'LR'],
#  ['morgan', 'TOX21_GR_BLA_Agonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_GR_BLA_Agonist_ratio', 'NB'],
#  ['morgan', 'TOX21_GR_BLA_Antagonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_GR_BLA_Antagonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_GR_BLA_Antagonist_ratio', 'RF'],
#  ['morgan', 'TOX21_GR_BLA_Antagonist_ratio', 'LR'],
#  ['morgan', 'TOX21_GR_BLA_Antagonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_GR_BLA_Antagonist_ratio', 'NB'],
#  ['morgan', 'TOX21_ARE_BLA_agonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_ARE_BLA_agonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_ARE_BLA_agonist_ratio', 'RF'],
#  ['morgan', 'TOX21_ARE_BLA_agonist_ratio', 'LR'],
#  ['morgan', 'TOX21_ARE_BLA_agonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_ARE_BLA_agonist_ratio', 'NB'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Agonist', 'MLP'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Agonist', 'GBT'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Agonist', 'RF'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Agonist', 'LR'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Agonist', 'KNN'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Agonist', 'NB'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Antagonist', 'MLP'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Antagonist', 'GBT'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Antagonist', 'RF'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Antagonist', 'LR'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Antagonist', 'KNN'],
#  ['morgan', 'TOX21_TR_LUC_GH3_Antagonist', 'NB'],
#  ['morgan', 'TOX21_PPARg_BLA_Agonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_PPARg_BLA_Agonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_PPARg_BLA_Agonist_ratio', 'RF'],
#  ['morgan', 'TOX21_PPARg_BLA_Agonist_ratio', 'LR'],
#  ['morgan', 'TOX21_PPARg_BLA_Agonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_PPARg_BLA_Agonist_ratio', 'NB'],
#  ['morgan', 'TOX21_PPARd_BLA_agonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_PPARd_BLA_agonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_PPARd_BLA_agonist_ratio', 'RF'],
#  ['morgan', 'TOX21_PPARd_BLA_agonist_ratio', 'LR'],
#  ['morgan', 'TOX21_PPARd_BLA_agonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_PPARd_BLA_agonist_ratio', 'NB'],
#  ['morgan', 'TOX21_PPARd_BLA_antagonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_PPARd_BLA_antagonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_PPARd_BLA_antagonist_ratio', 'RF'],
#  ['morgan', 'TOX21_PPARd_BLA_antagonist_ratio', 'LR'],
#  ['morgan', 'TOX21_PPARd_BLA_antagonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_PPARd_BLA_antagonist_ratio', 'NB'],
#  ['morgan', 'TOX21_PPARg_BLA_antagonist_ratio', 'MLP'],
#  ['morgan', 'TOX21_PPARg_BLA_antagonist_ratio', 'GBT'],
#  ['morgan', 'TOX21_PPARg_BLA_antagonist_ratio', 'RF'],
#  ['morgan', 'TOX21_PPARg_BLA_antagonist_ratio', 'LR'],
#  ['morgan', 'TOX21_PPARg_BLA_antagonist_ratio', 'KNN'],
#  ['morgan', 'TOX21_PPARg_BLA_antagonist_ratio', 'NB'],
#  ['rdkit', 'NVS_ADME_hCYP1A2', 'MLP'],
#  ['rdkit', 'NVS_ADME_hCYP1A2', 'GBT'],
#  ['rdkit', 'NVS_ADME_hCYP1A2', 'RF'],
#  ['rdkit', 'NVS_ADME_hCYP1A2', 'LR'],
#  ['rdkit', 'NVS_ADME_hCYP1A2', 'KNN'],
#  ['rdkit', 'NVS_ADME_hCYP1A2', 'NB'],
#  ['rdkit', 'NVS_ADME_hCYP2B6', 'MLP'],
#  ['rdkit', 'NVS_ADME_hCYP2B6', 'GBT'],
#  ['rdkit', 'NVS_ADME_hCYP2B6', 'RF'],
#  ['rdkit', 'NVS_ADME_hCYP2B6', 'LR'],
#  ['rdkit', 'NVS_ADME_hCYP2B6', 'KNN'],
#  ['rdkit', 'NVS_ADME_hCYP2B6', 'NB'],
#  ['rdkit', 'NCCT_TPO_AUR_dn', 'MLP'],
#  ['rdkit', 'NCCT_TPO_AUR_dn', 'GBT'],
#  ['rdkit', 'NCCT_TPO_AUR_dn', 'RF'],
#  ['rdkit', 'NCCT_TPO_AUR_dn', 'LR'],
#  ['rdkit', 'NCCT_TPO_AUR_dn', 'KNN'],
#  ['rdkit', 'NCCT_TPO_AUR_dn', 'NB'],
#  ['rdkit', 'TOX21_AhR_LUC_Agonist', 'MLP'],
#  ['rdkit', 'TOX21_AhR_LUC_Agonist', 'GBT'],
#  ['rdkit', 'TOX21_AhR_LUC_Agonist', 'RF'],
#  ['rdkit', 'TOX21_AhR_LUC_Agonist', 'LR'],
#  ['rdkit', 'TOX21_AhR_LUC_Agonist', 'KNN'],
#  ['rdkit', 'TOX21_AhR_LUC_Agonist', 'NB'],
#  ['rdkit', 'TOX21_Aromatase_Inhibition', 'MLP'],
#  ['rdkit', 'TOX21_Aromatase_Inhibition', 'GBT'],
#  ['rdkit', 'TOX21_Aromatase_Inhibition', 'RF'],
#  ['rdkit', 'TOX21_Aromatase_Inhibition', 'LR'],
#  ['rdkit', 'TOX21_Aromatase_Inhibition', 'KNN'],
#  ['rdkit', 'TOX21_Aromatase_Inhibition', 'NB'],
#  ['rdkit', 'TOX21_VDR_BLA_agonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_VDR_BLA_agonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_VDR_BLA_agonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_VDR_BLA_agonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_VDR_BLA_agonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_VDR_BLA_agonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_VDR_BLA_antagonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_VDR_BLA_antagonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_VDR_BLA_antagonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_VDR_BLA_antagonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_VDR_BLA_antagonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_VDR_BLA_antagonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_AR_BLA_Agonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_AR_BLA_Agonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_AR_BLA_Agonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_AR_BLA_Agonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_AR_BLA_Agonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_AR_BLA_Agonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_AR_BLA_Antagonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_AR_BLA_Antagonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_AR_BLA_Antagonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_AR_BLA_Antagonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_AR_BLA_Antagonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_AR_BLA_Antagonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_AR_LUC_MDAKB2_Agonist', 'MLP'],
#  ['rdkit', 'TOX21_AR_LUC_MDAKB2_Agonist', 'GBT'],
#  ['rdkit', 'TOX21_AR_LUC_MDAKB2_Agonist', 'RF'],
#  ['rdkit', 'TOX21_AR_LUC_MDAKB2_Agonist', 'LR'],
#  ['rdkit', 'TOX21_AR_LUC_MDAKB2_Agonist', 'KNN'],
#  ['rdkit', 'TOX21_AR_LUC_MDAKB2_Agonist', 'NB'],
#  ['rdkit', 'TOX21_p53_BLA_p1_ratio', 'MLP'],
#  ['rdkit', 'TOX21_p53_BLA_p1_ratio', 'GBT'],
#  ['rdkit', 'TOX21_p53_BLA_p1_ratio', 'RF'],
#  ['rdkit', 'TOX21_p53_BLA_p1_ratio', 'LR'],
#  ['rdkit', 'TOX21_p53_BLA_p1_ratio', 'KNN'],
#  ['rdkit', 'TOX21_p53_BLA_p1_ratio', 'NB'],
#  ['rdkit', 'TOX21_p53_BLA_p2_ratio', 'MLP'],
#  ['rdkit', 'TOX21_p53_BLA_p2_ratio', 'GBT'],
#  ['rdkit', 'TOX21_p53_BLA_p2_ratio', 'RF'],
#  ['rdkit', 'TOX21_p53_BLA_p2_ratio', 'LR'],
#  ['rdkit', 'TOX21_p53_BLA_p2_ratio', 'KNN'],
#  ['rdkit', 'TOX21_p53_BLA_p2_ratio', 'NB'],
#  ['rdkit', 'TOX21_p53_BLA_p3_ratio', 'MLP'],
#  ['rdkit', 'TOX21_p53_BLA_p3_ratio', 'GBT'],
#  ['rdkit', 'TOX21_p53_BLA_p3_ratio', 'RF'],
#  ['rdkit', 'TOX21_p53_BLA_p3_ratio', 'LR'],
#  ['rdkit', 'TOX21_p53_BLA_p3_ratio', 'KNN'],
#  ['rdkit', 'TOX21_p53_BLA_p3_ratio', 'NB'],
#  ['rdkit', 'TOX21_p53_BLA_p4_ratio', 'MLP'],
#  ['rdkit', 'TOX21_p53_BLA_p4_ratio', 'GBT'],
#  ['rdkit', 'TOX21_p53_BLA_p4_ratio', 'RF'],
#  ['rdkit', 'TOX21_p53_BLA_p4_ratio', 'LR'],
#  ['rdkit', 'TOX21_p53_BLA_p4_ratio', 'KNN'],
#  ['rdkit', 'TOX21_p53_BLA_p4_ratio', 'NB'],
#  ['rdkit', 'TOX21_p53_BLA_p5_ratio', 'MLP'],
#  ['rdkit', 'TOX21_p53_BLA_p5_ratio', 'GBT'],
#  ['rdkit', 'TOX21_p53_BLA_p5_ratio', 'RF'],
#  ['rdkit', 'TOX21_p53_BLA_p5_ratio', 'LR'],
#  ['rdkit', 'TOX21_p53_BLA_p5_ratio', 'KNN'],
#  ['rdkit', 'TOX21_p53_BLA_p5_ratio', 'NB'],
#  ['rdkit', 'TOX21_HSE_BLA_agonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_HSE_BLA_agonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_HSE_BLA_agonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_HSE_BLA_agonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_HSE_BLA_agonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_HSE_BLA_agonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_ELG1_LUC_Agonist', 'MLP'],
#  ['rdkit', 'TOX21_ELG1_LUC_Agonist', 'GBT'],
#  ['rdkit', 'TOX21_ELG1_LUC_Agonist', 'RF'],
#  ['rdkit', 'TOX21_ELG1_LUC_Agonist', 'LR'],
#  ['rdkit', 'TOX21_ELG1_LUC_Agonist', 'KNN'],
#  ['rdkit', 'TOX21_ELG1_LUC_Agonist', 'NB'],
#  ['rdkit', 'TOX21_ERa_BLA_Agonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_ERa_BLA_Agonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_ERa_BLA_Agonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_ERa_BLA_Agonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_ERa_BLA_Agonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_ERa_BLA_Agonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_ERa_BLA_Antagonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_ERa_BLA_Antagonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_ERa_BLA_Antagonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_ERa_BLA_Antagonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_ERa_BLA_Antagonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_ERa_BLA_Antagonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_ESRE_BLA_ratio', 'MLP'],
#  ['rdkit', 'TOX21_ESRE_BLA_ratio', 'GBT'],
#  ['rdkit', 'TOX21_ESRE_BLA_ratio', 'RF'],
#  ['rdkit', 'TOX21_ESRE_BLA_ratio', 'LR'],
#  ['rdkit', 'TOX21_ESRE_BLA_ratio', 'KNN'],
#  ['rdkit', 'TOX21_ESRE_BLA_ratio', 'NB'],
#  ['rdkit', 'TOX21_FXR_BLA_agonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_FXR_BLA_agonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_FXR_BLA_agonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_FXR_BLA_agonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_FXR_BLA_agonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_FXR_BLA_agonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_FXR_BLA_antagonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_FXR_BLA_antagonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_FXR_BLA_antagonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_FXR_BLA_antagonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_FXR_BLA_antagonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_FXR_BLA_antagonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_GR_BLA_Agonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_GR_BLA_Agonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_GR_BLA_Agonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_GR_BLA_Agonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_GR_BLA_Agonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_GR_BLA_Agonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_GR_BLA_Antagonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_GR_BLA_Antagonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_GR_BLA_Antagonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_GR_BLA_Antagonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_GR_BLA_Antagonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_GR_BLA_Antagonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_ARE_BLA_agonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_ARE_BLA_agonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_ARE_BLA_agonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_ARE_BLA_agonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_ARE_BLA_agonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_ARE_BLA_agonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Agonist', 'MLP'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Agonist', 'GBT'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Agonist', 'RF'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Agonist', 'LR'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Agonist', 'KNN'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Agonist', 'NB'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Antagonist', 'MLP'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Antagonist', 'GBT'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Antagonist', 'RF'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Antagonist', 'LR'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Antagonist', 'KNN'],
#  ['rdkit', 'TOX21_TR_LUC_GH3_Antagonist', 'NB'],
#  ['rdkit', 'TOX21_PPARg_BLA_Agonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_PPARg_BLA_Agonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_PPARg_BLA_Agonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_PPARg_BLA_Agonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_PPARg_BLA_Agonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_PPARg_BLA_Agonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_PPARd_BLA_agonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_PPARd_BLA_agonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_PPARd_BLA_agonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_PPARd_BLA_agonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_PPARd_BLA_agonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_PPARd_BLA_agonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_PPARd_BLA_antagonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_PPARd_BLA_antagonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_PPARd_BLA_antagonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_PPARd_BLA_antagonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_PPARd_BLA_antagonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_PPARd_BLA_antagonist_ratio', 'NB'],
#  ['rdkit', 'TOX21_PPARg_BLA_antagonist_ratio', 'MLP'],
#  ['rdkit', 'TOX21_PPARg_BLA_antagonist_ratio', 'GBT'],
#  ['rdkit', 'TOX21_PPARg_BLA_antagonist_ratio', 'RF'],
#  ['rdkit', 'TOX21_PPARg_BLA_antagonist_ratio', 'LR'],
#  ['rdkit', 'TOX21_PPARg_BLA_antagonist_ratio', 'KNN'],
#  ['rdkit', 'TOX21_PPARg_BLA_antagonist_ratio', 'NB'],
#  ['pattern', 'NVS_ADME_hCYP1A2', 'MLP'],
#  ['pattern', 'NVS_ADME_hCYP1A2', 'GBT'],
#  ['pattern', 'NVS_ADME_hCYP1A2', 'RF'],
#  ['pattern', 'NVS_ADME_hCYP1A2', 'LR'],
#  ['pattern', 'NVS_ADME_hCYP1A2', 'KNN'],
#  ['pattern', 'NVS_ADME_hCYP1A2', 'NB'],
#  ['pattern', 'NVS_ADME_hCYP2B6', 'MLP'],
#  ['pattern', 'NVS_ADME_hCYP2B6', 'GBT'],
#  ['pattern', 'NVS_ADME_hCYP2B6', 'RF'],
#  ['pattern', 'NVS_ADME_hCYP2B6', 'LR'],
#  ['pattern', 'NVS_ADME_hCYP2B6', 'KNN'],
#  ['pattern', 'NVS_ADME_hCYP2B6', 'NB'],
#  ['pattern', 'NCCT_TPO_AUR_dn', 'MLP'],
#  ['pattern', 'NCCT_TPO_AUR_dn', 'GBT'],
#  ['pattern', 'NCCT_TPO_AUR_dn', 'RF'],
#  ['pattern', 'NCCT_TPO_AUR_dn', 'LR'],
#  ['pattern', 'NCCT_TPO_AUR_dn', 'KNN'],
#  ['pattern', 'NCCT_TPO_AUR_dn', 'NB'],
#  ['pattern', 'TOX21_AhR_LUC_Agonist', 'MLP'],
#  ['pattern', 'TOX21_AhR_LUC_Agonist', 'GBT'],
#  ['pattern', 'TOX21_AhR_LUC_Agonist', 'RF'],
#  ['pattern', 'TOX21_AhR_LUC_Agonist', 'LR'],
#  ['pattern', 'TOX21_AhR_LUC_Agonist', 'KNN'],
#  ['pattern', 'TOX21_AhR_LUC_Agonist', 'NB'],
#  ['pattern', 'TOX21_Aromatase_Inhibition', 'MLP'],
#  ['pattern', 'TOX21_Aromatase_Inhibition', 'GBT'],
#  ['pattern', 'TOX21_Aromatase_Inhibition', 'RF'],
#  ['pattern', 'TOX21_Aromatase_Inhibition', 'LR'],
#  ['pattern', 'TOX21_Aromatase_Inhibition', 'KNN'],
#  ['pattern', 'TOX21_Aromatase_Inhibition', 'NB'],
#  ['pattern', 'TOX21_VDR_BLA_agonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_VDR_BLA_agonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_VDR_BLA_agonist_ratio', 'RF'],
#  ['pattern', 'TOX21_VDR_BLA_agonist_ratio', 'LR'],
#  ['pattern', 'TOX21_VDR_BLA_agonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_VDR_BLA_agonist_ratio', 'NB'],
#  ['pattern', 'TOX21_VDR_BLA_antagonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_VDR_BLA_antagonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_VDR_BLA_antagonist_ratio', 'RF'],
#  ['pattern', 'TOX21_VDR_BLA_antagonist_ratio', 'LR'],
#  ['pattern', 'TOX21_VDR_BLA_antagonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_VDR_BLA_antagonist_ratio', 'NB'],
#  ['pattern', 'TOX21_AR_BLA_Agonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_AR_BLA_Agonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_AR_BLA_Agonist_ratio', 'RF'],
#  ['pattern', 'TOX21_AR_BLA_Agonist_ratio', 'LR'],
#  ['pattern', 'TOX21_AR_BLA_Agonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_AR_BLA_Agonist_ratio', 'NB'],
#  ['pattern', 'TOX21_AR_BLA_Antagonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_AR_BLA_Antagonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_AR_BLA_Antagonist_ratio', 'RF'],
#  ['pattern', 'TOX21_AR_BLA_Antagonist_ratio', 'LR'],
#  ['pattern', 'TOX21_AR_BLA_Antagonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_AR_BLA_Antagonist_ratio', 'NB'],
#  ['pattern', 'TOX21_AR_LUC_MDAKB2_Agonist', 'MLP'],
#  ['pattern', 'TOX21_AR_LUC_MDAKB2_Agonist', 'GBT'],
#  ['pattern', 'TOX21_AR_LUC_MDAKB2_Agonist', 'RF'],
#  ['pattern', 'TOX21_AR_LUC_MDAKB2_Agonist', 'LR'],
#  ['pattern', 'TOX21_AR_LUC_MDAKB2_Agonist', 'KNN'],
#  ['pattern', 'TOX21_AR_LUC_MDAKB2_Agonist', 'NB'],
#  ['pattern', 'TOX21_p53_BLA_p1_ratio', 'MLP'],
#  ['pattern', 'TOX21_p53_BLA_p1_ratio', 'GBT'],
#  ['pattern', 'TOX21_p53_BLA_p1_ratio', 'RF'],
#  ['pattern', 'TOX21_p53_BLA_p1_ratio', 'LR'],
#  ['pattern', 'TOX21_p53_BLA_p1_ratio', 'KNN'],
#  ['pattern', 'TOX21_p53_BLA_p1_ratio', 'NB'],
#  ['pattern', 'TOX21_p53_BLA_p2_ratio', 'MLP'],
#  ['pattern', 'TOX21_p53_BLA_p2_ratio', 'GBT'],
#  ['pattern', 'TOX21_p53_BLA_p2_ratio', 'RF'],
#  ['pattern', 'TOX21_p53_BLA_p2_ratio', 'LR'],
#  ['pattern', 'TOX21_p53_BLA_p2_ratio', 'KNN'],
#  ['pattern', 'TOX21_p53_BLA_p2_ratio', 'NB'],
#  ['pattern', 'TOX21_p53_BLA_p3_ratio', 'MLP'],
#  ['pattern', 'TOX21_p53_BLA_p3_ratio', 'GBT'],
#  ['pattern', 'TOX21_p53_BLA_p3_ratio', 'RF'],
#  ['pattern', 'TOX21_p53_BLA_p3_ratio', 'LR'],
#  ['pattern', 'TOX21_p53_BLA_p3_ratio', 'KNN'],
#  ['pattern', 'TOX21_p53_BLA_p3_ratio', 'NB'],
#  ['pattern', 'TOX21_p53_BLA_p4_ratio', 'MLP'],
#  ['pattern', 'TOX21_p53_BLA_p4_ratio', 'GBT'],
#  ['pattern', 'TOX21_p53_BLA_p4_ratio', 'RF'],
#  ['pattern', 'TOX21_p53_BLA_p4_ratio', 'LR'],
#  ['pattern', 'TOX21_p53_BLA_p4_ratio', 'KNN'],
#  ['pattern', 'TOX21_p53_BLA_p4_ratio', 'NB'],
#  ['pattern', 'TOX21_p53_BLA_p5_ratio', 'MLP'],
#  ['pattern', 'TOX21_p53_BLA_p5_ratio', 'GBT'],
#  ['pattern', 'TOX21_p53_BLA_p5_ratio', 'RF'],
#  ['pattern', 'TOX21_p53_BLA_p5_ratio', 'LR'],
#  ['pattern', 'TOX21_p53_BLA_p5_ratio', 'KNN'],
#  ['pattern', 'TOX21_p53_BLA_p5_ratio', 'NB'],
#  ['pattern', 'TOX21_HSE_BLA_agonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_HSE_BLA_agonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_HSE_BLA_agonist_ratio', 'RF'],
#  ['pattern', 'TOX21_HSE_BLA_agonist_ratio', 'LR'],
#  ['pattern', 'TOX21_HSE_BLA_agonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_HSE_BLA_agonist_ratio', 'NB'],
#  ['pattern', 'TOX21_ELG1_LUC_Agonist', 'MLP'],
#  ['pattern', 'TOX21_ELG1_LUC_Agonist', 'GBT'],
#  ['pattern', 'TOX21_ELG1_LUC_Agonist', 'RF'],
#  ['pattern', 'TOX21_ELG1_LUC_Agonist', 'LR'],
#  ['pattern', 'TOX21_ELG1_LUC_Agonist', 'KNN'],
#  ['pattern', 'TOX21_ELG1_LUC_Agonist', 'NB'],
#  ['pattern', 'TOX21_ERa_BLA_Agonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_ERa_BLA_Agonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_ERa_BLA_Agonist_ratio', 'RF'],
#  ['pattern', 'TOX21_ERa_BLA_Agonist_ratio', 'LR'],
#  ['pattern', 'TOX21_ERa_BLA_Agonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_ERa_BLA_Agonist_ratio', 'NB'],
#  ['pattern', 'TOX21_ERa_BLA_Antagonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_ERa_BLA_Antagonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_ERa_BLA_Antagonist_ratio', 'RF'],
#  ['pattern', 'TOX21_ERa_BLA_Antagonist_ratio', 'LR'],
#  ['pattern', 'TOX21_ERa_BLA_Antagonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_ERa_BLA_Antagonist_ratio', 'NB'],
#  ['pattern', 'TOX21_ESRE_BLA_ratio', 'MLP'],
#  ['pattern', 'TOX21_ESRE_BLA_ratio', 'GBT'],
#  ['pattern', 'TOX21_ESRE_BLA_ratio', 'RF'],
#  ['pattern', 'TOX21_ESRE_BLA_ratio', 'LR'],
#  ['pattern', 'TOX21_ESRE_BLA_ratio', 'KNN'],
#  ['pattern', 'TOX21_ESRE_BLA_ratio', 'NB'],
#  ['pattern', 'TOX21_FXR_BLA_agonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_FXR_BLA_agonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_FXR_BLA_agonist_ratio', 'RF'],
#  ['pattern', 'TOX21_FXR_BLA_agonist_ratio', 'LR'],
#  ['pattern', 'TOX21_FXR_BLA_agonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_FXR_BLA_agonist_ratio', 'NB'],
#  ['pattern', 'TOX21_FXR_BLA_antagonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_FXR_BLA_antagonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_FXR_BLA_antagonist_ratio', 'RF'],
#  ['pattern', 'TOX21_FXR_BLA_antagonist_ratio', 'LR'],
#  ['pattern', 'TOX21_FXR_BLA_antagonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_FXR_BLA_antagonist_ratio', 'NB'],
#  ['pattern', 'TOX21_GR_BLA_Agonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_GR_BLA_Agonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_GR_BLA_Agonist_ratio', 'RF'],
#  ['pattern', 'TOX21_GR_BLA_Agonist_ratio', 'LR'],
#  ['pattern', 'TOX21_GR_BLA_Agonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_GR_BLA_Agonist_ratio', 'NB'],
#  ['pattern', 'TOX21_GR_BLA_Antagonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_GR_BLA_Antagonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_GR_BLA_Antagonist_ratio', 'RF'],
#  ['pattern', 'TOX21_GR_BLA_Antagonist_ratio', 'LR'],
#  ['pattern', 'TOX21_GR_BLA_Antagonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_GR_BLA_Antagonist_ratio', 'NB'],
#  ['pattern', 'TOX21_ARE_BLA_agonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_ARE_BLA_agonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_ARE_BLA_agonist_ratio', 'RF'],
#  ['pattern', 'TOX21_ARE_BLA_agonist_ratio', 'LR'],
#  ['pattern', 'TOX21_ARE_BLA_agonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_ARE_BLA_agonist_ratio', 'NB'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Agonist', 'MLP'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Agonist', 'GBT'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Agonist', 'RF'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Agonist', 'LR'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Agonist', 'KNN'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Agonist', 'NB'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Antagonist', 'MLP'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Antagonist', 'GBT'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Antagonist', 'RF'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Antagonist', 'LR'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Antagonist', 'KNN'],
#  ['pattern', 'TOX21_TR_LUC_GH3_Antagonist', 'NB'],
#  ['pattern', 'TOX21_PPARg_BLA_Agonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_PPARg_BLA_Agonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_PPARg_BLA_Agonist_ratio', 'RF'],
#  ['pattern', 'TOX21_PPARg_BLA_Agonist_ratio', 'LR'],
#  ['pattern', 'TOX21_PPARg_BLA_Agonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_PPARg_BLA_Agonist_ratio', 'NB'],
#  ['pattern', 'TOX21_PPARd_BLA_agonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_PPARd_BLA_agonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_PPARd_BLA_agonist_ratio', 'RF'],
#  ['pattern', 'TOX21_PPARd_BLA_agonist_ratio', 'LR'],
#  ['pattern', 'TOX21_PPARd_BLA_agonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_PPARd_BLA_agonist_ratio', 'NB'],
#  ['pattern', 'TOX21_PPARd_BLA_antagonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_PPARd_BLA_antagonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_PPARd_BLA_antagonist_ratio', 'RF'],
#  ['pattern', 'TOX21_PPARd_BLA_antagonist_ratio', 'LR'],
#  ['pattern', 'TOX21_PPARd_BLA_antagonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_PPARd_BLA_antagonist_ratio', 'NB'],
#  ['pattern', 'TOX21_PPARg_BLA_antagonist_ratio', 'MLP'],
#  ['pattern', 'TOX21_PPARg_BLA_antagonist_ratio', 'GBT'],
#  ['pattern', 'TOX21_PPARg_BLA_antagonist_ratio', 'RF'],
#  ['pattern', 'TOX21_PPARg_BLA_antagonist_ratio', 'LR'],
#  ['pattern', 'TOX21_PPARg_BLA_antagonist_ratio', 'KNN'],
#  ['pattern', 'TOX21_PPARg_BLA_antagonist_ratio', 'NB'],
#  ['layerd', 'NVS_ADME_hCYP1A2', 'MLP'],
#  ['layerd', 'NVS_ADME_hCYP1A2', 'GBT'],
#  ['layerd', 'NVS_ADME_hCYP1A2', 'RF'],
#  ['layerd', 'NVS_ADME_hCYP1A2', 'LR'],
#  ['layerd', 'NVS_ADME_hCYP1A2', 'KNN'],
#  ['layerd', 'NVS_ADME_hCYP1A2', 'NB'],
#  ['layerd', 'NVS_ADME_hCYP2B6', 'MLP'],
#  ['layerd', 'NVS_ADME_hCYP2B6', 'GBT'],
#  ['layerd', 'NVS_ADME_hCYP2B6', 'RF'],
#  ['layerd', 'NVS_ADME_hCYP2B6', 'LR'],
#  ['layerd', 'NVS_ADME_hCYP2B6', 'KNN'],
#  ['layerd', 'NVS_ADME_hCYP2B6', 'NB'],
#  ['layerd', 'NCCT_TPO_AUR_dn', 'MLP'],
#  ['layerd', 'NCCT_TPO_AUR_dn', 'GBT'],
#  ['layerd', 'NCCT_TPO_AUR_dn', 'RF'],
#  ['layerd', 'NCCT_TPO_AUR_dn', 'LR'],
#  ['layerd', 'NCCT_TPO_AUR_dn', 'KNN'],
#  ['layerd', 'NCCT_TPO_AUR_dn', 'NB'],
#  ['layerd', 'TOX21_AhR_LUC_Agonist', 'MLP'],
#  ['layerd', 'TOX21_AhR_LUC_Agonist', 'GBT'],
#  ['layerd', 'TOX21_AhR_LUC_Agonist', 'RF'],
#  ['layerd', 'TOX21_AhR_LUC_Agonist', 'LR'],
#  ['layerd', 'TOX21_AhR_LUC_Agonist', 'KNN'],
#  ['layerd', 'TOX21_AhR_LUC_Agonist', 'NB'],
#  ['layerd', 'TOX21_Aromatase_Inhibition', 'MLP'],
#  ['layerd', 'TOX21_Aromatase_Inhibition', 'GBT'],
#  ['layerd', 'TOX21_Aromatase_Inhibition', 'RF'],
#  ['layerd', 'TOX21_Aromatase_Inhibition', 'LR'],
#  ['layerd', 'TOX21_Aromatase_Inhibition', 'KNN'],
#  ['layerd', 'TOX21_Aromatase_Inhibition', 'NB'],
#  ['layerd', 'TOX21_VDR_BLA_agonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_VDR_BLA_agonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_VDR_BLA_agonist_ratio', 'RF'],
#  ['layerd', 'TOX21_VDR_BLA_agonist_ratio', 'LR'],
#  ['layerd', 'TOX21_VDR_BLA_agonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_VDR_BLA_agonist_ratio', 'NB'],
#  ['layerd', 'TOX21_VDR_BLA_antagonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_VDR_BLA_antagonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_VDR_BLA_antagonist_ratio', 'RF'],
#  ['layerd', 'TOX21_VDR_BLA_antagonist_ratio', 'LR'],
#  ['layerd', 'TOX21_VDR_BLA_antagonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_VDR_BLA_antagonist_ratio', 'NB'],
#  ['layerd', 'TOX21_AR_BLA_Agonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_AR_BLA_Agonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_AR_BLA_Agonist_ratio', 'RF'],
#  ['layerd', 'TOX21_AR_BLA_Agonist_ratio', 'LR'],
#  ['layerd', 'TOX21_AR_BLA_Agonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_AR_BLA_Agonist_ratio', 'NB'],
#  ['layerd', 'TOX21_AR_BLA_Antagonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_AR_BLA_Antagonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_AR_BLA_Antagonist_ratio', 'RF'],
#  ['layerd', 'TOX21_AR_BLA_Antagonist_ratio', 'LR'],
#  ['layerd', 'TOX21_AR_BLA_Antagonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_AR_BLA_Antagonist_ratio', 'NB'],
#  ['layerd', 'TOX21_AR_LUC_MDAKB2_Agonist', 'MLP'],
#  ['layerd', 'TOX21_AR_LUC_MDAKB2_Agonist', 'GBT'],
#  ['layerd', 'TOX21_AR_LUC_MDAKB2_Agonist', 'RF'],
#  ['layerd', 'TOX21_AR_LUC_MDAKB2_Agonist', 'LR'],
#  ['layerd', 'TOX21_AR_LUC_MDAKB2_Agonist', 'KNN'],
#  ['layerd', 'TOX21_AR_LUC_MDAKB2_Agonist', 'NB'],
#  ['layerd', 'TOX21_p53_BLA_p1_ratio', 'MLP'],
#  ['layerd', 'TOX21_p53_BLA_p1_ratio', 'GBT'],
#  ['layerd', 'TOX21_p53_BLA_p1_ratio', 'RF'],
#  ['layerd', 'TOX21_p53_BLA_p1_ratio', 'LR'],
#  ['layerd', 'TOX21_p53_BLA_p1_ratio', 'KNN'],
#  ['layerd', 'TOX21_p53_BLA_p1_ratio', 'NB'],
#  ['layerd', 'TOX21_p53_BLA_p2_ratio', 'MLP'],
#  ['layerd', 'TOX21_p53_BLA_p2_ratio', 'GBT'],
#  ['layerd', 'TOX21_p53_BLA_p2_ratio', 'RF'],
#  ['layerd', 'TOX21_p53_BLA_p2_ratio', 'LR'],
#  ['layerd', 'TOX21_p53_BLA_p2_ratio', 'KNN'],
#  ['layerd', 'TOX21_p53_BLA_p2_ratio', 'NB'],
#  ['layerd', 'TOX21_p53_BLA_p3_ratio', 'MLP'],
#  ['layerd', 'TOX21_p53_BLA_p3_ratio', 'GBT'],
#  ['layerd', 'TOX21_p53_BLA_p3_ratio', 'RF'],
#  ['layerd', 'TOX21_p53_BLA_p3_ratio', 'LR'],
#  ['layerd', 'TOX21_p53_BLA_p3_ratio', 'KNN'],
#  ['layerd', 'TOX21_p53_BLA_p3_ratio', 'NB'],
#  ['layerd', 'TOX21_p53_BLA_p4_ratio', 'MLP'],
#  ['layerd', 'TOX21_p53_BLA_p4_ratio', 'GBT'],
#  ['layerd', 'TOX21_p53_BLA_p4_ratio', 'RF'],
#  ['layerd', 'TOX21_p53_BLA_p4_ratio', 'LR'],
#  ['layerd', 'TOX21_p53_BLA_p4_ratio', 'KNN'],
#  ['layerd', 'TOX21_p53_BLA_p4_ratio', 'NB'],
#  ['layerd', 'TOX21_p53_BLA_p5_ratio', 'MLP'],
#  ['layerd', 'TOX21_p53_BLA_p5_ratio', 'GBT'],
#  ['layerd', 'TOX21_p53_BLA_p5_ratio', 'RF'],
#  ['layerd', 'TOX21_p53_BLA_p5_ratio', 'LR'],
#  ['layerd', 'TOX21_p53_BLA_p5_ratio', 'KNN'],
#  ['layerd', 'TOX21_p53_BLA_p5_ratio', 'NB'],
#  ['layerd', 'TOX21_HSE_BLA_agonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_HSE_BLA_agonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_HSE_BLA_agonist_ratio', 'RF'],
#  ['layerd', 'TOX21_HSE_BLA_agonist_ratio', 'LR'],
#  ['layerd', 'TOX21_HSE_BLA_agonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_HSE_BLA_agonist_ratio', 'NB'],
#  ['layerd', 'TOX21_ELG1_LUC_Agonist', 'MLP'],
#  ['layerd', 'TOX21_ELG1_LUC_Agonist', 'GBT'],
#  ['layerd', 'TOX21_ELG1_LUC_Agonist', 'RF'],
#  ['layerd', 'TOX21_ELG1_LUC_Agonist', 'LR'],
#  ['layerd', 'TOX21_ELG1_LUC_Agonist', 'KNN'],
#  ['layerd', 'TOX21_ELG1_LUC_Agonist', 'NB'],
#  ['layerd', 'TOX21_ERa_BLA_Agonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_ERa_BLA_Agonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_ERa_BLA_Agonist_ratio', 'RF'],
#  ['layerd', 'TOX21_ERa_BLA_Agonist_ratio', 'LR'],
#  ['layerd', 'TOX21_ERa_BLA_Agonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_ERa_BLA_Agonist_ratio', 'NB'],
#  ['layerd', 'TOX21_ERa_BLA_Antagonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_ERa_BLA_Antagonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_ERa_BLA_Antagonist_ratio', 'RF'],
#  ['layerd', 'TOX21_ERa_BLA_Antagonist_ratio', 'LR'],
#  ['layerd', 'TOX21_ERa_BLA_Antagonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_ERa_BLA_Antagonist_ratio', 'NB'],
#  ['layerd', 'TOX21_ESRE_BLA_ratio', 'MLP'],
#  ['layerd', 'TOX21_ESRE_BLA_ratio', 'GBT'],
#  ['layerd', 'TOX21_ESRE_BLA_ratio', 'RF'],
#  ['layerd', 'TOX21_ESRE_BLA_ratio', 'LR'],
#  ['layerd', 'TOX21_ESRE_BLA_ratio', 'KNN'],
#  ['layerd', 'TOX21_ESRE_BLA_ratio', 'NB'],
#  ['layerd', 'TOX21_FXR_BLA_agonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_FXR_BLA_agonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_FXR_BLA_agonist_ratio', 'RF'],
#  ['layerd', 'TOX21_FXR_BLA_agonist_ratio', 'LR'],
#  ['layerd', 'TOX21_FXR_BLA_agonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_FXR_BLA_agonist_ratio', 'NB'],
#  ['layerd', 'TOX21_FXR_BLA_antagonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_FXR_BLA_antagonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_FXR_BLA_antagonist_ratio', 'RF'],
#  ['layerd', 'TOX21_FXR_BLA_antagonist_ratio', 'LR'],
#  ['layerd', 'TOX21_FXR_BLA_antagonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_FXR_BLA_antagonist_ratio', 'NB'],
#  ['layerd', 'TOX21_GR_BLA_Agonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_GR_BLA_Agonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_GR_BLA_Agonist_ratio', 'RF'],
#  ['layerd', 'TOX21_GR_BLA_Agonist_ratio', 'LR'],
#  ['layerd', 'TOX21_GR_BLA_Agonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_GR_BLA_Agonist_ratio', 'NB'],
#  ['layerd', 'TOX21_GR_BLA_Antagonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_GR_BLA_Antagonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_GR_BLA_Antagonist_ratio', 'RF'],
#  ['layerd', 'TOX21_GR_BLA_Antagonist_ratio', 'LR'],
#  ['layerd', 'TOX21_GR_BLA_Antagonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_GR_BLA_Antagonist_ratio', 'NB'],
#  ['layerd', 'TOX21_ARE_BLA_agonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_ARE_BLA_agonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_ARE_BLA_agonist_ratio', 'RF'],
#  ['layerd', 'TOX21_ARE_BLA_agonist_ratio', 'LR'],
#  ['layerd', 'TOX21_ARE_BLA_agonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_ARE_BLA_agonist_ratio', 'NB'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Agonist', 'MLP'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Agonist', 'GBT'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Agonist', 'RF'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Agonist', 'LR'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Agonist', 'KNN'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Agonist', 'NB'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Antagonist', 'MLP'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Antagonist', 'GBT'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Antagonist', 'RF'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Antagonist', 'LR'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Antagonist', 'KNN'],
#  ['layerd', 'TOX21_TR_LUC_GH3_Antagonist', 'NB'],
#  ['layerd', 'TOX21_PPARg_BLA_Agonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_PPARg_BLA_Agonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_PPARg_BLA_Agonist_ratio', 'RF'],
#  ['layerd', 'TOX21_PPARg_BLA_Agonist_ratio', 'LR'],
#  ['layerd', 'TOX21_PPARg_BLA_Agonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_PPARg_BLA_Agonist_ratio', 'NB'],
#  ['layerd', 'TOX21_PPARd_BLA_agonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_PPARd_BLA_agonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_PPARd_BLA_agonist_ratio', 'RF'],
#  ['layerd', 'TOX21_PPARd_BLA_agonist_ratio', 'LR'],
#  ['layerd', 'TOX21_PPARd_BLA_agonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_PPARd_BLA_agonist_ratio', 'NB'],
#  ['layerd', 'TOX21_PPARd_BLA_antagonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_PPARd_BLA_antagonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_PPARd_BLA_antagonist_ratio', 'RF'],
#  ['layerd', 'TOX21_PPARd_BLA_antagonist_ratio', 'LR'],
#  ['layerd', 'TOX21_PPARd_BLA_antagonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_PPARd_BLA_antagonist_ratio', 'NB'],
#  ['layerd', 'TOX21_PPARg_BLA_antagonist_ratio', 'MLP'],
#  ['layerd', 'TOX21_PPARg_BLA_antagonist_ratio', 'GBT'],
#  ['layerd', 'TOX21_PPARg_BLA_antagonist_ratio', 'RF'],
#  ['layerd', 'TOX21_PPARg_BLA_antagonist_ratio', 'LR'],
#  ['layerd', 'TOX21_PPARg_BLA_antagonist_ratio', 'KNN'],
#  ['layerd', 'TOX21_PPARg_BLA_antagonist_ratio', 'NB']]

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import multiprocessing
CPU_CORE = multiprocessing.cpu_count() # 멀티프로세싱 CPU 사용 수
if __name__=='__main__':
    pool = multiprocessing.Pool(processes=CPU_CORE)
    pool.map(g_tf, a_p_list)
    pool.close()
    pool.join()
# Out:
# maccs MLP NVS_ADME_hCYP2B6 start!_______________________________
# maccs MLP NVS_ADME_hCYP1A2 start!_______________________________
# maccs MLP NCCT_TPO_AUR_dn start!_______________________________
# maccs MLP TOX21_Aromatase_Inhibition start!_______________________________
# maccs MLP TOX21_VDR_BLA_agonist_ratio start!_______________________________
# maccs MLP TOX21_VDR_BLA_antagonist_ratio start!_______________________________
# maccs MLP TOX21_AhR_LUC_Agonist start!_______________________________
# maccs MLP TOX21_AR_BLA_Agonist_ratio start!_______________________________
# maccs MLP TOX21_AR_LUC_MDAKB2_Agonist start!_______________________________
# maccs MLP TOX21_AR_BLA_Antagonist_ratio start!_______________________________
# maccs MLP TOX21_p53_BLA_p1_ratio start!_______________________________
# maccs MLP TOX21_p53_BLA_p3_ratio start!_______________________________
# maccs MLP TOX21_p53_BLA_p4_ratio start!_______________________________
# maccs MLP TOX21_p53_BLA_p2_ratio start!_______________________________
# maccs MLP TOX21_p53_BLA_p5_ratio start!_______________________________
# maccs MLP TOX21_ELG1_LUC_Agonist start!_______________________________
# maccs MLP TOX21_ERa_BLA_Agonist_ratio start!_______________________________
# maccs MLP TOX21_HSE_BLA_agonist_ratio start!_______________________________
# maccs MLP TOX21_GR_BLA_Agonist_ratio start!_______________________________
# maccs MLP TOX21_ESRE_BLA_ratio start!_______________________________
# maccs MLP TOX21_FXR_BLA_agonist_ratio start!_______________________________
# maccs MLP TOX21_ERa_BLA_Antagonist_ratio start!_______________________________
# maccs MLP TOX21_FXR_BLA_antagonist_ratio start!_______________________________
# maccs MLP TOX21_ARE_BLA_agonist_ratio start!_______________________________
# maccs MLP TOX21_PPARg_BLA_Agonist_ratio start!_______________________________
# maccs MLP TOX21_GR_BLA_Antagonist_ratio start!_______________________________
# maccs MLP TOX21_TR_LUC_GH3_Antagonist start!_______________________________
# maccs MLP TOX21_TR_LUC_GH3_Agonist start!_______________________________
# maccs MLP TOX21_PPARd_BLA_agonist_ratio start!_______________________________
# maccs MLP TOX21_PPARd_BLA_antagonist_ratio start!_______________________________
# morgan MLP NVS_ADME_hCYP1A2 start!_______________________________
# maccs MLP TOX21_PPARg_BLA_antagonist_ratio start!_______________________________
# morgan MLP NVS_ADME_hCYP2B6 start!_______________________________
# morgan MLP TOX21_AhR_LUC_Agonist start!_______________________________
# morgan MLP TOX21_Aromatase_Inhibition start!_______________________________
# morgan MLP TOX21_AR_BLA_Agonist_ratio start!_______________________________
# morgan MLP TOX21_AR_BLA_Antagonist_ratio start!_______________________________
# morgan MLP NCCT_TPO_AUR_dn start!_______________________________
# morgan MLP TOX21_VDR_BLA_antagonist_ratio start!_______________________________
# morgan MLP TOX21_VDR_BLA_agonist_ratio start!_______________________________
# maccs MLP NVS_ADME_hCYP2B6 end time spent -69.55711007118225
# maccs GBT NVS_ADME_hCYP2B6 start!_______________________________
# maccs MLP NVS_ADME_hCYP1A2 end time spent -72.25580286979675
# maccs GBT NVS_ADME_hCYP1A2 start!_______________________________
# SMOTEENN fitiing.... morgan MLP TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_VDR_BLA_antagonist_ratio
# maccs GBT NVS_ADME_hCYP2B6 end time spent -12.63677978515625
# maccs RF NVS_ADME_hCYP2B6 start!_______________________________
# SMOTEENN fitiing.... morgan MLP TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... morgan MLP TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... morgan MLP TOX21_AR_BLA_Agonist_ratio
# maccs GBT NVS_ADME_hCYP1A2 end time spent -14.529032230377197
# maccs RF NVS_ADME_hCYP1A2 start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_HSE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ARE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p4_ratio
# maccs RF NVS_ADME_hCYP2B6 end time spent -18.23590087890625
# maccs LR NVS_ADME_hCYP2B6 start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p3_ratio
# maccs LR NVS_ADME_hCYP2B6 end time spent -7.791585206985474
# maccs KNN NVS_ADME_hCYP2B6 start!_______________________________
# maccs RF NVS_ADME_hCYP1A2 end time spent -21.579593420028687
# maccs LR NVS_ADME_hCYP1A2 start!_______________________________
# maccs KNN NVS_ADME_hCYP2B6 end time spent -2.7623543739318848
# maccs NB NVS_ADME_hCYP2B6 start!_______________________________
# maccs NB NVS_ADME_hCYP2B6 end time spent -2.871260166168213
# morgan MLP TOX21_AR_LUC_MDAKB2_Agonist start!_______________________________
# maccs LR NVS_ADME_hCYP1A2 end time spent -8.374876022338867
# maccs KNN NVS_ADME_hCYP1A2 start!_______________________________
# maccs KNN NVS_ADME_hCYP1A2 end time spent -3.349013328552246
# maccs NB NVS_ADME_hCYP1A2 start!_______________________________
# morgan MLP NVS_ADME_hCYP2B6 end time spent -121.06868648529053
# morgan GBT NVS_ADME_hCYP2B6 start!_______________________________
# maccs NB NVS_ADME_hCYP1A2 end time spent -1.8105132579803467
# morgan MLP TOX21_p53_BLA_p1_ratio start!_______________________________
# morgan GBT NVS_ADME_hCYP2B6 end time spent -24.898683786392212
# morgan RF NVS_ADME_hCYP2B6 start!_______________________________
# morgan MLP NVS_ADME_hCYP1A2 end time spent -148.3798315525055
# morgan GBT NVS_ADME_hCYP1A2 start!_______________________________
# morgan RF NVS_ADME_hCYP2B6 end time spent -17.13104271888733
# morgan LR NVS_ADME_hCYP2B6 start!_______________________________
# morgan LR NVS_ADME_hCYP2B6 end time spent -6.1728835105896
# morgan KNN NVS_ADME_hCYP2B6 start!_______________________________
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p1_ratio
# morgan KNN NVS_ADME_hCYP2B6 end time spent -2.99771785736084
# morgan NB NVS_ADME_hCYP2B6 start!_______________________________
# SMOTEENN fitiing.... morgan MLP TOX21_AR_LUC_MDAKB2_Agonist
# morgan NB NVS_ADME_hCYP2B6 end time spent -2.2721478939056396
# morgan MLP TOX21_p53_BLA_p2_ratio start!_______________________________
# morgan GBT NVS_ADME_hCYP1A2 end time spent -26.53227972984314
# morgan RF NVS_ADME_hCYP1A2 start!_______________________________
# morgan RF NVS_ADME_hCYP1A2 end time spent -17.27916693687439
# morgan LR NVS_ADME_hCYP1A2 start!_______________________________
# morgan LR NVS_ADME_hCYP1A2 end time spent -7.4030656814575195
# morgan KNN NVS_ADME_hCYP1A2 start!_______________________________
# morgan KNN NVS_ADME_hCYP1A2 end time spent -3.6884377002716064
# morgan NB NVS_ADME_hCYP1A2 start!_______________________________
# morgan NB NVS_ADME_hCYP1A2 end time spent -2.6685523986816406
# morgan MLP TOX21_p53_BLA_p3_ratio start!_______________________________
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p3_ratio
# maccs MLP NCCT_TPO_AUR_dn end time spent -258.77830815315247
# maccs GBT NCCT_TPO_AUR_dn start!_______________________________
# maccs GBT NCCT_TPO_AUR_dn end time spent -13.471932649612427
# maccs RF NCCT_TPO_AUR_dn start!_______________________________
# maccs RF NCCT_TPO_AUR_dn end time spent -13.390227317810059
# maccs LR NCCT_TPO_AUR_dn start!_______________________________
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# maccs LR NCCT_TPO_AUR_dn end time spent -14.461782693862915
# maccs KNN NCCT_TPO_AUR_dn start!_______________________________
# maccs KNN NCCT_TPO_AUR_dn end time spent -7.219717741012573
# maccs NB NCCT_TPO_AUR_dn start!_______________________________
# maccs NB NCCT_TPO_AUR_dn end time spent -5.553495645523071
# morgan MLP TOX21_p53_BLA_p4_ratio start!_______________________________
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Agonist
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs MLP TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Antagonist_ratio
# morgan MLP NCCT_TPO_AUR_dn end time spent -866.019686460495
# morgan GBT NCCT_TPO_AUR_dn start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs MLP TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# morgan GBT NCCT_TPO_AUR_dn end time spent -132.71950602531433
# morgan RF NCCT_TPO_AUR_dn start!_______________________________
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# morgan RF NCCT_TPO_AUR_dn end time spent -49.682945728302
# morgan LR NCCT_TPO_AUR_dn start!_______________________________
# morgan LR NCCT_TPO_AUR_dn end time spent -18.535876035690308
# morgan KNN NCCT_TPO_AUR_dn start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_agonist_ratio
# morgan KNN NCCT_TPO_AUR_dn end time spent -43.83083486557007
# morgan NB NCCT_TPO_AUR_dn start!_______________________________
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# morgan NB NCCT_TPO_AUR_dn end time spent -11.267298221588135
# morgan MLP TOX21_p53_BLA_p5_ratio start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_HSE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ARE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_agonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Agonist
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_agonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ARE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing morgan TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_HSE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_AR_LUC_MDAKB2_Agonist
# maccs MLP TOX21_VDR_BLA_antagonist_ratio end time spent -4788.136624336243
# maccs GBT TOX21_VDR_BLA_antagonist_ratio start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs MLP TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# maccs MLP TOX21_VDR_BLA_agonist_ratio end time spent -5079.733139038086
# maccs GBT TOX21_VDR_BLA_agonist_ratio start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p4_ratio
# maccs MLP TOX21_FXR_BLA_agonist_ratio end time spent -5397.4881246089935
# maccs GBT TOX21_FXR_BLA_agonist_ratio start!_______________________________
# ....End fitiing morgan TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# maccs MLP TOX21_ESRE_BLA_ratio end time spent -5568.857934713364
# maccs GBT TOX21_ESRE_BLA_ratio start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p1_ratio
# maccs MLP TOX21_PPARd_BLA_agonist_ratio end time spent -5863.671494483948
# maccs GBT TOX21_PPARd_BLA_agonist_ratio start!_______________________________
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_Aromatase_Inhibition
# maccs MLP TOX21_TR_LUC_GH3_Agonist end time spent -5907.34502530098
# maccs GBT TOX21_TR_LUC_GH3_Agonist start!_______________________________
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# maccs MLP TOX21_PPARd_BLA_antagonist_ratio end time spent -5940.163467168808
# maccs GBT TOX21_PPARd_BLA_antagonist_ratio start!_______________________________
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs GBT TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# ....End fitiing morgan TOX21_AR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ARE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Antagonist_ratio
# maccs MLP TOX21_FXR_BLA_antagonist_ratio end time spent -6340.510393619537
# maccs GBT TOX21_FXR_BLA_antagonist_ratio start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_agonist_ratio
# ....End fitiing morgan TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# ....End fitiing morgan TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing morgan TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# ....End fitiing morgan TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_PPARd_BLA_agonist_ratio
# maccs MLP TOX21_HSE_BLA_agonist_ratio end time spent -6616.445656299591
# SMOTEENN fitiing.... morgan MLP TOX21_AR_BLA_Antagonist_ratio
# maccs GBT TOX21_HSE_BLA_agonist_ratio start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_HSE_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... morgan MLP TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Agonist_ratio
# ....End fitiing morgan TOX21_p53_BLA_p2_ratio
# maccs MLP TOX21_PPARg_BLA_antagonist_ratio end time spent -6845.881137371063
# maccs GBT TOX21_PPARg_BLA_antagonist_ratio start!_______________________________
# SMOTEENN fitiing.... maccs GBT TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs MLP TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing morgan TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# ....End fitiing morgan TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_agonist_ratio
# maccs MLP TOX21_ELG1_LUC_Agonist end time spent -6987.794500589371
# maccs GBT TOX21_ELG1_LUC_Agonist start!_______________________________
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# maccs MLP TOX21_ARE_BLA_agonist_ratio end time spent -7035.9140820503235
# maccs GBT TOX21_ARE_BLA_agonist_ratio start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs GBT TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs GBT TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_AR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# ....End fitiing morgan TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_PPARd_BLA_agonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# maccs MLP TOX21_GR_BLA_Agonist_ratio end time spent -7323.86985206604
# maccs GBT TOX21_GR_BLA_Agonist_ratio start!_______________________________
# SMOTEENN fitiing.... maccs GBT TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# maccs MLP TOX21_GR_BLA_Antagonist_ratio end time spent -7374.56552028656
# maccs GBT TOX21_GR_BLA_Antagonist_ratio start!_______________________________
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_ESRE_BLA_ratio
# maccs MLP TOX21_Aromatase_Inhibition end time spent -7466.492168903351
# maccs GBT TOX21_Aromatase_Inhibition start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_FXR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# maccs MLP TOX21_AR_BLA_Agonist_ratio end time spent -7609.231653213501
# maccs GBT TOX21_AR_BLA_Agonist_ratio start!_______________________________
# maccs MLP TOX21_PPARg_BLA_Agonist_ratio end time spent -7619.395918607712
# maccs GBT TOX21_PPARg_BLA_Agonist_ratio start!_______________________________
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_FXR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p2_ratio
# maccs MLP TOX21_ERa_BLA_Agonist_ratio end time spent -7675.347318410873
# maccs GBT TOX21_ERa_BLA_Agonist_ratio start!_______________________________
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs GBT TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_PPARd_BLA_agonist_ratio
# ....End fitiing morgan TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_VDR_BLA_antagonist_ratio
# maccs MLP TOX21_AhR_LUC_Agonist end time spent -7791.280264616013
# maccs GBT TOX21_AhR_LUC_Agonist start!_______________________________
# SMOTEENN fitiing.... maccs GBT TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_FXR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs GBT TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_HSE_BLA_agonist_ratio
# maccs MLP TOX21_TR_LUC_GH3_Antagonist end time spent -7824.0025861263275
# maccs GBT TOX21_TR_LUC_GH3_Antagonist start!_______________________________
# SMOTEENN fitiing.... maccs MLP TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_ESRE_BLA_ratio
# maccs MLP TOX21_AR_LUC_MDAKB2_Agonist end time spent -7869.173687696457
# maccs GBT TOX21_AR_LUC_MDAKB2_Agonist start!_______________________________
# SMOTEENN fitiing.... maccs GBT TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... maccs GBT TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_VDR_BLA_agonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_TR_LUC_GH3_Antagonist
# maccs MLP TOX21_AR_BLA_Antagonist_ratio end time spent -7918.818320512772
# maccs GBT TOX21_AR_BLA_Antagonist_ratio start!_______________________________
# SMOTEENN fitiing.... maccs GBT TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# maccs MLP TOX21_ERa_BLA_Antagonist_ratio end time spent -7936.653619289398
# maccs GBT TOX21_ERa_BLA_Antagonist_ratio start!_______________________________
# SMOTEENN fitiing.... maccs GBT TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs GBT TOX21_ESRE_BLA_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_antagonist_ratio
# ...
# SMOTEENN fitiing.... maccs NB TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing morgan TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing morgan TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs NB TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs NB TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_AR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_VDR_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing morgan TOX21_AR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_HSE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing morgan TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs NB TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_AR_BLA_Antagonist_ratio
# ....End fitiing morgan TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs NB TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_ELG1_LUC_Agonist
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p3_ratio
# ....End fitiing morgan TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_GR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_AR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# SMOTEENN fitiing.... maccs NB TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... morgan MLP TOX21_Aromatase_Inhibition
# ....End fitiing morgan TOX21_ARE_BLA_agonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_AR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs NB TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_ELG1_LUC_Agonist
# SMOTEENN fitiing.... morgan MLP TOX21_FXR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_GR_BLA_Agonist_ratio
# maccs NB TOX21_GR_BLA_Agonist_ratio end time spent -2666.5442922115326
# morgan MLP TOX21_TR_LUC_GH3_Antagonist start!_______________________________
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_TR_LUC_GH3_Antagonist
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_TR_LUC_GH3_Antagonist
# maccs NB TOX21_TR_LUC_GH3_Antagonist end time spent -2537.197090625763
# morgan MLP TOX21_PPARg_BLA_Agonist_ratio start!_______________________________
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_AR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs NB TOX21_Aromatase_Inhibition
# ....End fitiing morgan TOX21_GR_BLA_Agonist_ratio
# ....End fitiing morgan TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing morgan TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_ELG1_LUC_Agonist
# maccs NB TOX21_ELG1_LUC_Agonist end time spent -2638.4191274642944
# morgan MLP TOX21_PPARd_BLA_agonist_ratio start!_______________________________
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p2_ratio
# ....End fitiing morgan TOX21_p53_BLA_p3_ratio
# ....End fitiing morgan TOX21_AhR_LUC_Agonist
# ....End fitiing morgan TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_ARE_BLA_agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_PPARd_BLA_agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_VDR_BLA_antagonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_GR_BLA_Agonist_ratio
# ....End fitiing morgan TOX21_TR_LUC_GH3_Agonist
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_GR_BLA_Antagonist_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... maccs NB TOX21_AR_LUC_MDAKB2_Agonist
# SMOTEENN fitiing.... morgan MLP TOX21_AR_LUC_MDAKB2_Agonist
# ....End fitiing maccs TOX21_AR_BLA_Antagonist_ratio
# maccs NB TOX21_AR_BLA_Antagonist_ratio end time spent -2765.721184015274
# morgan MLP TOX21_PPARd_BLA_antagonist_ratio start!_______________________________
# SMOTEENN fitiing.... morgan MLP TOX21_TR_LUC_GH3_Agonist
# SMOTEENN fitiing.... morgan MLP TOX21_PPARd_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs NB TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_GR_BLA_Antagonist_ratio
# maccs NB TOX21_GR_BLA_Antagonist_ratio end time spent -2805.9798917770386
# morgan MLP TOX21_PPARg_BLA_antagonist_ratio start!_______________________________
# SMOTEENN fitiing.... morgan MLP TOX21_PPARg_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p3_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_AhR_LUC_Agonist
# maccs NB TOX21_AhR_LUC_Agonist end time spent -2802.3331592082977
# rdkit MLP NVS_ADME_hCYP1A2 start!_______________________________
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_AR_LUC_MDAKB2_Agonist
# maccs NB TOX21_AR_LUC_MDAKB2_Agonist end time spent -2745.2796182632446
# rdkit MLP NVS_ADME_hCYP2B6 start!_______________________________
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_PPARg_BLA_Agonist_ratio
# ....End fitiing morgan TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_AR_BLA_Agonist_ratio
# maccs NB TOX21_AR_BLA_Agonist_ratio end time spent -2833.38755607605
# rdkit MLP NCCT_TPO_AUR_dn start!_______________________________
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# SMOTEENN fitiing.... maccs NB TOX21_Aromatase_Inhibition
# rdkit MLP NVS_ADME_hCYP2B6 end time spent -163.50136947631836
# rdkit GBT NVS_ADME_hCYP2B6 start!_______________________________
# rdkit MLP NVS_ADME_hCYP1A2 end time spent -184.0349018573761
# rdkit GBT NVS_ADME_hCYP1A2 start!_______________________________
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p5_ratio
# rdkit GBT NVS_ADME_hCYP2B6 end time spent -48.744770526885986
# rdkit RF NVS_ADME_hCYP2B6 start!_______________________________
# rdkit RF NVS_ADME_hCYP2B6 end time spent -11.80463981628418
# rdkit LR NVS_ADME_hCYP2B6 start!_______________________________
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_ERa_BLA_Antagonist_ratio
# rdkit GBT NVS_ADME_hCYP1A2 end time spent -64.88332271575928
# rdkit RF NVS_ADME_hCYP1A2 start!_______________________________
# rdkit LR NVS_ADME_hCYP2B6 end time spent -11.053008079528809
# rdkit KNN NVS_ADME_hCYP2B6 start!_______________________________
# rdkit KNN NVS_ADME_hCYP2B6 end time spent -3.684473991394043
# rdkit NB NVS_ADME_hCYP2B6 start!_______________________________
# rdkit NB NVS_ADME_hCYP2B6 end time spent -3.3293633460998535
# rdkit MLP TOX21_AhR_LUC_Agonist start!_______________________________
# rdkit RF NVS_ADME_hCYP1A2 end time spent -17.333966970443726
# rdkit LR NVS_ADME_hCYP1A2 start!_______________________________
# rdkit LR NVS_ADME_hCYP1A2 end time spent -12.905348777770996
# rdkit KNN NVS_ADME_hCYP1A2 start!_______________________________
# rdkit KNN NVS_ADME_hCYP1A2 end time spent -5.797236442565918
# rdkit NB NVS_ADME_hCYP1A2 start!_______________________________
# rdkit NB NVS_ADME_hCYP1A2 end time spent -3.155027389526367
# rdkit MLP TOX21_Aromatase_Inhibition start!_______________________________
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p3_ratio
# SMOTEENN fitiing.... morgan MLP TOX21_p53_BLA_p1_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... rdkit MLP TOX21_AhR_LUC_Agonist
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Agonist_ratio
# maccs NB TOX21_ERa_BLA_Agonist_ratio end time spent -2927.2057859897614
# rdkit MLP TOX21_VDR_BLA_agonist_ratio start!_______________________________
# SMOTEENN fitiing.... rdkit MLP TOX21_Aromatase_Inhibition
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... maccs NB TOX21_PPARg_BLA_Agonist_ratio
# SMOTEENN fitiing.... rdkit MLP TOX21_VDR_BLA_agonist_ratio
# ....End fitiing morgan TOX21_p53_BLA_p2_ratio
# ....End fitiing maccs TOX21_Aromatase_Inhibition
# maccs NB TOX21_Aromatase_Inhibition end time spent -2963.5141792297363
# rdkit MLP TOX21_VDR_BLA_antagonist_ratio start!_______________________________
# ....End fitiing maccs TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p2_ratio
# SMOTEENN fitiing.... rdkit MLP TOX21_VDR_BLA_antagonist_ratio
# ....End fitiing maccs TOX21_ERa_BLA_Antagonist_ratio
# maccs NB TOX21_ERa_BLA_Antagonist_ratio end time spent -2970.3766837120056
# rdkit MLP TOX21_AR_BLA_Agonist_ratio start!_______________________________
# ....End fitiing maccs TOX21_p53_BLA_p5_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p5_ratio
# ....End fitiing maccs TOX21_p53_BLA_p3_ratio
# maccs NB TOX21_p53_BLA_p3_ratio end time spent -3027.6607904434204
# rdkit MLP TOX21_AR_BLA_Antagonist_ratio start!_______________________________
# SMOTEENN fitiing.... rdkit MLP TOX21_AR_BLA_Agonist_ratio
# ....End fitiing maccs TOX21_p53_BLA_p1_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p1_ratio
# rdkit MLP TOX21_AR_LUC_MDAKB2_Agonist start!_______________________________
# ....End fitiing maccs TOX21_p53_BLA_p4_ratio
# SMOTEENN fitiing.... maccs NB TOX21_p53_BLA_p4_ratio
# ....End fitiing maccs TOX21_PPARg_BLA_Agonist_ratio
# maccs NB TOX21_PPARg_BLA_Agonist_ratio end time spent -3019.545426607132
# rdkit MLP TOX21_p53_BLA_p1_ratio start!_______________________________
# SMOTEENN fitiing.... rdkit MLP TOX21_AR_BLA_Antagonist_ratio

# %%
ss_fp = a_p_list[10]
ffpp = ss_fp[0]#fingerfrint name
ss =ss_fp[1]#assay name
# ffpp = "maccs"

df_ss = df.loc[:,['smiles',ss]]
df_ss = df_ss.dropna()
assays_ss = df_ss.columns

#Smiles --> MACCS Keys
assay = ss
df_train  = df_ss[['smiles',ss] ]

smiles_list = []
err_smiles = []# fingerfrint로 변환시 에러 smiles
fps = []
enc_y = []
for index, row in df_train.iterrows():

  if row[-1] == 'N' : 
    target = 0
  else :
    target = 1

  try : 
    mol = Chem.MolFromSmiles(row['smiles'])
    
    if ffpp == 'maccs' :    
        fp = MACCSkeys.GenMACCSKeys(mol)
    elif ffpp == 'morgan' : 
        fp = Chem.AllChem.GetMorganFingerprintAsBitVect(mol, 2)
    elif ffpp == 'rdkit' : 
        fp = Chem.RDKFingerprint(mol)
    elif ffpp == 'pattern' : 
        fp = Chem.rdmolops.PatternFingerprint(mol)
    elif ffpp == 'layerd' : 
        fp = Chem.rdmolops.LayeredFingerprint(mol)
    else : 
        print("fingerfrint selection error!")
        
    smiles_list.append(row['smiles'])   
    fps.append(fp)
    enc_y.append(target)
  except : 
    err_smiles.append(row['smiles'])
    pass

np_fps = []
for fp in fps:
  arr = numpy.zeros((1,))
  DataStructs.ConvertToNumpyArray(fp, arr)
  np_fps.append(arr)

np_fps_array = numpy.array(np_fps)

# print("변환 에러난 smiles 개수 : ", len(err_smiles), err_smiles)

x_train_res, y_train_res = np_fps_array, np.array(enc_y)
train = pd.DataFrame(data=x_train_res)
train['label'] = y_train_res

d = pd.DataFrame(columns = ['smiles','Type'] )
d['smiles'] = smiles_list
d['Type'] = enc_y

#모든 물질에 대한 fingerprint를 string형태로 바꾼다(비교하기위함).
mychems = []
for item in np_fps:
    #print(item)
    item = np.array(item,dtype=int) #왜 굳이 두번? int형으로 추가하려면 이렇게 하면 되는구나....
    s = item.tolist() #넘파이어레이를 리스트로 바꾼다. 
    t = [str(i) for i in s]
    mychems.append(''.join(t))

i = 0
counter = 0
chemdict = {} #딗셔너리.
listofdups = []
for item in mychems:
    try:
        chemdict[str(item)].append(i)
        #print('dup found')
        for j in range(len(chemdict[str(item)])):
            if (d['Type'][i] != d['Type'][chemdict[str(item)][j]]) :
                listofdups.append(i)
                counter+=1
    except: 
        #print('adding new')
        chemdict[str(item)] = []
        chemdict[str(item)].append(i)
    i+=1
# print(str(counter)+' '+str(len(list(set(listofdups)))))
#smote적용하기 전에서 listofdups를 빼면 된다!

dups_list = list(set(listofdups))

dups_list_0 = []
for index in dups_list : 
  if train.iloc[index].label == 0 :
    dups_list_0.append(index)

train = train.drop(dups_list_0)

#분산이 0인 feature 제거
train = train.loc[ :, train.std() > 0]



# rskf = RepeatedStratifiedKFold(n_splits=10, n_repeats=10, random_state=36851234) 
rskf = StratifiedKFold(n_splits = 10, random_state = 42)
sme = SMOTEENN(random_state=42,sampling_strategy = "minority")

X = np.array( train.drop('label', axis =1) )
y = np.array(train.label)

count = 0 
rep = 0

metric_df = pd.DataFrame(columns = ['AUC','B_A','Recall','Precision','F1','MCC','Accuracy'])
metric_fold_df = pd.DataFrame(columns = ['AUC','B_A','Recall','Precision','F1','MCC','Accuracy'])

for train_index, test_index in rskf.split(X, y): 
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]
  if ss in ['NVS_ADME_hCYP1A2' , 'NVS_ADME_hCYP2B6' , 'NCCT_TPO_AUR_dn'] : 
    pass
  else : 
    print("SMOTEENN fitiing....",ffpp, ss)
    X_train, y_train = sme.fit_sample(X_train, list(y_train) )
    print("....End fitiing",ffpp, ss)
  
  clf = RandomForestClassifier()
  clf.fit(X_train, y_train)

  result =  clf.predict_proba(X_test) # 첫 클래스의 예측확률, 두번째 클래스의 예측 확률 어떤것이 0, 1이지?
  y_pred = clf.predict(X_test)
  conf_mat = confusion_matrix(y_test,y_pred)
  tn, fp, fn, tp = conf_mat.ravel()

  auc =  roc_auc_score(y_test,result[:,1] )
  recall = tp/(tp+fn) # 실제 1인 것 중 모델이 1이라 한것의 비율
  specificity = tn / (fp+tn) # 실제 0인 것중 모델이 0이라한것의 비율
  b_a = (recall + specificity) / 2
  precision =  tp / (tp+fp)
  F1 = 2* (precision * recall) / (precision + recall)
  MCC = matthews_corrcoef(y_test,y_pred)
  accuracy = clf.score(X_test,y_test)


  metric_fold_df = metric_fold_df.append(pd.DataFrame([[auc,b_a,recall,precision,F1,MCC,accuracy]],columns = ['AUC','B_A','Recall','Precision','F1','MCC','Accuracy']) )
  count +=1
  # print(ffpp, ss, count)
  if count % 10 == 0 :
    average = metric_fold_df.mean()
    std = metric_fold_df.std()
    metric_fold_df = metric_fold_df.append(average.to_frame().T)
    metric_fold_df = metric_fold_df.append(std.to_frame().T)
    metric_fold_df = round(metric_fold_df ,4)
    metric_fold_df.index = [str(rep) +'_' +  str(i) for i in range(10)]+ [str(rep)+'_Mean' , str(rep)+'_SD']
    metric_df = metric_df.append(metric_fold_df)
    metric_fold_df = pd.DataFrame(columns = ['AUC','B_A','Recall','Precision','F1','MCC','Accuracy'])
    rep += 1
    # print(ffpp, ss, rep)
  

#전체 평균내기.
bool_list = [] 
for i in metric_df.index :
  if'Mean' in i  or 'SD' in i : 
    bool_list.append(False) 
  else : 
    bool_list.append(True)

average = metric_df[bool_list].mean().to_frame().T
average.index = ['Mean']
std = metric_df[bool_list].std().to_frame().T
std.index =['SD']

metric_df = metric_df.append(round(average,4) )
metric_df = metric_df.append(round(std,4))
metric_df.to_csv(dir_path+"metric/"+ffpp+'/'+algorithm+'/'+ss+"_metric.csv")
print(ffpp, ss, 'end')

# %%
os.listdir('/content/result_sklearn/metric/')

# %%
df_list = [] 
for i in os.listdir('/content/result_sklearn/metric/') :
  df_list.append(pd.read_csv('/content/result_sklearn/metric/'+i) )

# %%
df_list[8]

# %%
# !gsutil cp -r ./result_sklearn gs://chem_dsrc/P0_Toxcast/

# %%
# !gsutil cp -r ./result_sklearn_all_a_fp gs://chem_dsrc/P0_Toxcast/
