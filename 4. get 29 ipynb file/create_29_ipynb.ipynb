# %%
file_name = '29_assays_dd.ipynb'

# %%
f = open(file_name,'r',encoding='UTF8')
file = f.readlines()

# %%
file
# Out:
# ['{\n',
#  ' "cells": [\n',
#  '  {\n',
#  '   "cell_type": "code",\n',
#  '   "execution_count": 29,\n',
#  '   "metadata": {\n',
#  '    "colab": {\n',
#  '     "base_uri": "https://localhost:8080/",\n',
#  '     "height": 17,\n',
#  '     "resources": {\n',
#  '      "http://localhost:8080/static/components/requirejs/require.js": {\n',
#  '       "data": "...",\n',
#  '       "headers": [\n',
#  '        [\n',
#  '         "content-type",\n',
#  '         "application/javascript"\n',
#  '        ]\n',
#  '       ],\n',
#  '       "ok": true,\n',
#  '       "status": 200,\n',
#  '       "status_text": ""\n',
#  '      }\n',
#  '     }\n',
#  '    },\n',
#  '    "id": "UJU5gTNcPBN8",\n',
#  '    "outputId": "64630067-d531-48c5-f786-3a8dad952cd7"\n',
#  '   },\n',
#  '   "outputs": [\n',
#  '    {\n',
#  '     "data": {\n',
#  '      "text/html": [\n',
#  '       "\\n",\n',
#  '       "            <script src=\\"/static/components/requirejs/require.js\\"></script>\\n",\n',
# ...

# %%
for i in range(100) : 
    if file[i] == '    "assay_index = 0"\n' : 
        print(i)
# Out:
# 54

# %%
file[54]
# Out:
# '    "assay_index = 0"\n'

# %%
file[8] = file[8].replace("0", str(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ceaff6b43db2> in <module>
# ----> 1 file[8] = file[8].replace("0", str(i))
#
# NameError: name 'i' is not defined

# %%
file[8]
# Out:
# '    "assay_index = 0"\n'

# %%
import os
os.mkdir('./29_assays_v5_duplicate_removed')

# %%
for i in range(0,30) : 
    f = open(file_name,'r',encoding='UTF8')
    file = f.readlines()
    f.close()
    file[54] = file[54].replace("0", str(i))

    g = open('./29_assays_v5_duplicate_removed/'+"29_assays_dm_"+str(i)+".ipynb", 'w+',encoding='UTF8')
    g.writelines(file)
    g.close()
