# %%
# !gsutil cp -r gs://chem_dsrc/P0_Toxcast/result_sklearn ./
# Out:
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/all_assay_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/NCCT_TPO_AUR_dn_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/NVS_ADME_hCYP1A2_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/NVS_ADME_hCYP2B6_dup_smiles_df.csv...
# \ [4 files][  2.9 KiB/  2.9 KiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_ARE_BLA_agonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_AR_BLA_Agonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_AR_BLA_Antagonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_AR_LUC_MDAKB2_Agonist_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_AhR_LUC_Agonist_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_Aromatase_Inhibition_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_ELG1_LUC_Agonist_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_ERa_BLA_Agonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_ERa_BLA_Antagonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_ESRE_BLA_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_FXR_BLA_agonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_FXR_BLA_antagonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_GR_BLA_Agonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_GR_BLA_Antagonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_HSE_BLA_agonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_PPARd_BLA_agonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_PPARd_BLA_antagonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_PPARg_BLA_Agonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_PPARg_BLA_antagonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_TR_LUC_GH3_Agonist_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_TR_LUC_GH3_Antagonist_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_VDR_BLA_agonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_VDR_BLA_antagonist_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_p53_BLA_p1_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_p53_BLA_p2_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_p53_BLA_p3_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_p53_BLA_p4_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/dup_smiles/TOX21_p53_BLA_p5_ratio_dup_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/NCCT_TPO_AUR_dn_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/NVS_ADME_hCYP1A2_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/NVS_ADME_hCYP2B6_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_ARE_BLA_agonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_AR_BLA_Agonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_AR_BLA_Antagonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_AR_LUC_MDAKB2_Agonist_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_AhR_LUC_Agonist_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_Aromatase_Inhibition_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_ELG1_LUC_Agonist_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_ERa_BLA_Agonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_ERa_BLA_Antagonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_ESRE_BLA_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_FXR_BLA_agonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_FXR_BLA_antagonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_GR_BLA_Agonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_GR_BLA_Antagonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_HSE_BLA_agonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_PPARd_BLA_agonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_PPARd_BLA_antagonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_PPARg_BLA_Agonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_PPARg_BLA_antagonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_TR_LUC_GH3_Agonist_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_TR_LUC_GH3_Antagonist_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_VDR_BLA_agonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_VDR_BLA_antagonist_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_p53_BLA_p1_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_p53_BLA_p2_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_p53_BLA_p3_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_p53_BLA_p4_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/err_smiles/TOX21_p53_BLA_p5_ratio_err_smiles_df.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/NCCT_TPO_AUR_dn_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/NVS_ADME_hCYP1A2_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/NVS_ADME_hCYP2B6_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_ARE_BLA_agonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_AR_BLA_Agonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_AR_BLA_Antagonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_AR_LUC_MDAKB2_Agonist_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_AhR_LUC_Agonist_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_Aromatase_Inhibition_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_ELG1_LUC_Agonist_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_ERa_BLA_Agonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_ERa_BLA_Antagonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_ESRE_BLA_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_FXR_BLA_agonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_FXR_BLA_antagonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_GR_BLA_Agonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_GR_BLA_Antagonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_HSE_BLA_agonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_PPARd_BLA_agonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_PPARd_BLA_antagonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_PPARg_BLA_Agonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_PPARg_BLA_antagonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_TR_LUC_GH3_Agonist_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_TR_LUC_GH3_Antagonist_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_VDR_BLA_agonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_VDR_BLA_antagonist_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_p53_BLA_p1_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_p53_BLA_p2_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_p53_BLA_p3_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_p53_BLA_p4_ratio_metric.csv...
# Copying gs://chem_dsrc/P0_Toxcast/result_sklearn/metric/TOX21_p53_BLA_p5_ratio_metric.csv...
# / [94 files][232.9 KiB/232.9 KiB]   18.2 KiB/s
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 94 objects/232.9 KiB.

# %%
import pandas as pd
# !gsutil cp gs://chem_dsrc/P0_Toxcast/result_sklearn/T2.csv ./
assay_names_df = pd.read_csv("assay_names.csv")

# %%
# selected_assay_list = ['NVS_ADME_hCYP1A2' , 'NVS_ADME_hCYP2B6' , 'NCCT_TPO_AUR_dn','TOX21_AhR_LUC_Agonist', 'TOX21_Aromatase_Inhibition', 'TOX21_VDR_BLA_agonist_ratio', 'TOX21_VDR_BLA_antagonist_ratio', 'TOX21_AR_BLA_Agonist_ratio', 'TOX21_AR_BLA_Antagonist_ratio', 'TOX21_AR_LUC_MDAKB2_Agonist', 'TOX21_p53_BLA_p1_ratio', 'TOX21_p53_BLA_p2_ratio', 'TOX21_p53_BLA_p3_ratio', 'TOX21_p53_BLA_p4_ratio', 'TOX21_p53_BLA_p5_ratio', 'TOX21_HSE_BLA_agonist_ratio', 'TOX21_ELG1_LUC_Agonist', 'TOX21_ERa_BLA_Agonist_ratio', 'TOX21_ERa_BLA_Antagonist_ratio', 'TOX21_ESRE_BLA_ratio', 'TOX21_FXR_BLA_agonist_ratio', 'TOX21_FXR_BLA_antagonist_ratio', 'TOX21_GR_BLA_Agonist_ratio', 'TOX21_GR_BLA_Antagonist_ratio', 'TOX21_NFkB_BLA_agonist_ratio', 'TOX21_ARE_BLA_agonist_ratio', 'TOX21_TR_LUC_GH3_Agonist', 'TOX21_TR_LUC_GH3_Antagonist', 'TOX21_PPARg_BLA_Agonist_ratio', 'TOX21_PPARd_BLA_agonist_ratio', 'TOX21_PPARd_BLA_antagonist_ratio', 'TOX21_PPARg_BLA_antagonist_ratio']
selected_assay_list = list( assay_names_df['Assay Name'] )
selected_assay_list.remove('TOX21_NFkB_BLA_agonist_ratio')

# %%
import pandas as pd
df = pd.DataFrame(columns =selected_assay_list, index = ['AUC','B_A','Recall','Precision','F1','MCC','Accuracy'])

# %%
df
# Out:
#           NVS_ADME_hCYP2B6  ... TOX21_PPARg_BLA_Agonist_ratio
# AUC                    NaN  ...                           NaN
# B_A                    NaN  ...                           NaN
# Recall                 NaN  ...                           NaN
# Precision              NaN  ...                           NaN
# F1                     NaN  ...                           NaN
# MCC                    NaN  ...                           NaN
# Accuracy               NaN  ...                           NaN
#
# [7 rows x 31 columns]

# %%
for assay in selected_assay_list : 
  result_df = pd.read_csv('/content/result_sklearn/metric/'+ assay+'_metric.csv')
  df[assay] = result_df.iloc[120][1:]
  # break

# %%
df.to_csv("all_assay_metric.csv")

# %%
# !gsutil cp all_assay_metric.csv gs://chem_dsrc/P0_Toxcast/result_sklearn/
# Out:
# Copying file://all_assay_metric.csv [Content-Type=text/csv]...
# / [1 files][  2.4 KiB/  2.4 KiB]
# Operation completed over 1 objects/2.4 KiB.

# %%
df
# Out:
#           NVS_ADME_hCYP2B6  ... TOX21_PPARg_BLA_Agonist_ratio
# AUC                 0.7679  ...                        0.8284
# B_A                 0.6743  ...                        0.5794
# Recall              0.8296  ...                        0.1629
# Precision            0.711  ...                         0.367
# F1                  0.7598  ...                        0.2423
# MCC                 0.3821  ...                        0.2329
# Accuracy            0.6997  ...                        0.9852
#
# [7 rows x 31 columns]

# %%
df.loc['AUC']
# Out:
# NVS_ADME_hCYP2B6                    0.7679
# NVS_ADME_hCYP1A2                    0.6188
# NCCT_TPO_AUR_dn                     0.7778
# TOX21_VDR_BLA_agonist_ratio         0.6732
# TOX21_VDR_BLA_antagonist_ratio      0.8233
# TOX21_HSE_BLA_agonist_ratio         0.7664
# TOX21_ESRE_BLA_ratio                0.8043
# TOX21_FXR_BLA_agonist_ratio         0.7243
# TOX21_FXR_BLA_antagonist_ratio      0.7343
# TOX21_ARE_BLA_agonist_ratio         0.7085
# TOX21_PPARd_BLA_agonist_ratio       0.7569
# TOX21_PPARd_BLA_antagonist_ratio    0.7596
# TOX21_PPARg_BLA_antagonist_ratio    0.8105
# TOX21_ELG1_LUC_Agonist              0.7917
# TOX21_AhR_LUC_Agonist               0.8354
# TOX21_Aromatase_Inhibition          0.7841
# TOX21_AR_BLA_Agonist_ratio          0.8314
# TOX21_AR_BLA_Antagonist_ratio       0.7479
# TOX21_AR_LUC_MDAKB2_Agonist         0.8027
# TOX21_p53_BLA_p1_ratio              0.8206
# TOX21_p53_BLA_p2_ratio              0.6999
# TOX21_p53_BLA_p3_ratio              0.7189
# TOX21_p53_BLA_p4_ratio              0.6565
# TOX21_p53_BLA_p5_ratio              0.6281
# TOX21_ERa_BLA_Agonist_ratio          0.772
# TOX21_ERa_BLA_Antagonist_ratio      0.7255
# TOX21_GR_BLA_Agonist_ratio          0.8704
# TOX21_GR_BLA_Antagonist_ratio       0.8243
# TOX21_TR_LUC_GH3_Agonist            0.7277
# TOX21_TR_LUC_GH3_Antagonist         0.7601
# TOX21_PPARg_BLA_Agonist_ratio       0.8284
# Name: AUC, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-6606fa877846> in <module>()
# ----> 1 assay_names_df['AUC (RF-MACCS)'] = list(df.loc['AUC'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3766
#    3767             # turn me into an ndarray
# -> 3768             value = sanitize_index(value, self.index)
#    3769             if not isinstance(value, (np.ndarray, Index)):
#    3770                 if isinstance(value, list) and len(value) > 0:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     746     if len(data) != len(index):
#     747         raise ValueError(
# --> 748             "Length of values "
#     749             f"({len(data)}) "
#     750             "does not match length of index "
#
# ValueError: Length of values (31) does not match length of index (32)

# %%
assay_names_df = assay_names_df[assay_names_df['Assay Name'] != 'TOX21_NFkB_BLA_agonist_ratio']

# %%
assay_names_df['AUC (RF-MACCS)'] = list(df.loc['AUC'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
assay_names_df['B_A (RF-MACCS)'] = list(df.loc['B_A'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
assay_names_df.to_csv("T2_result.csv")

# %%
# !gsutil cp T2_result.csv gs://chem_dsrc/P0_Toxcast/result_sklearn/
# Out:
# Copying file://T2_result.csv [Content-Type=text/csv]...
# / [1 files][  1.3 KiB/  1.3 KiB]
# Operation completed over 1 objects/1.3 KiB.
